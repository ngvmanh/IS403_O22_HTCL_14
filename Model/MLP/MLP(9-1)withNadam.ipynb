# %% [markdown]
# ## VCB

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import Nadam

pd.options.mode.chained_assignment = None
tf.random.set_seed(0)

# Load data
data = pd.read_csv('../../Dataset/VCB.csv')
df = data[['Date','Close']]
df.rename(columns={'Close': 'Price'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values('Date',inplace=True)
df.set_index('Date',inplace=True)
y = df['Price'].values.reshape(-1, 1)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
y_norm = scaler.fit_transform(y)

# Split data into train and test (90/10)
train_size = int(len(y_norm) * 0.9)
y_train, y_test = y_norm[:train_size], y_norm[train_size:]

# Create input and output sequences
def create_sequences(data, n_lookback, n_forecast):
    X, Y = [], []
    for i in range(n_lookback, len(data) - n_forecast + 1):
        X.append(data[i - n_lookback: i])
        Y.append(data[i: i + n_forecast])
    return np.array(X), np.array(Y)

n_lookback = 60
n_forecast = 1  # Predict time step
X_train, Y_train = create_sequences(y_train, n_lookback, n_forecast)
X_test, Y_test = create_sequences(y_test, n_lookback, n_forecast)

# Build and train the model
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(n_lookback,))) 
model.add(Dense(50, activation='relu'))                           
model.add(Dense(n_forecast))                                       

optimizer = Nadam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error')
model.fit(X_train.reshape(X_train.shape[0], -1), Y_train, epochs=200, validation_data=(X_test, Y_test), batch_size=32, verbose=1)

# Evaluate on the test set
Y_pred_test = model.predict(X_test.reshape(X_test.shape[0], -1))
Y_pred_test = scaler.inverse_transform(Y_pred_test)

# Reshape Y_test before inverse transforming
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))  # Reshape to 2D

# Predict future 30, 60, 90 days
last_sequence = y_norm[-n_lookback:].reshape(1, -1)
future_predictions = []
for i in range(90):
    next_pred = model.predict(last_sequence)
    future_predictions.append(next_pred)
    last_sequence = np.concatenate([last_sequence[:, 1:], next_pred], axis=1)  
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
# Out:
# Epoch 1/200
# c:\Users\ngoct\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0367 - val_loss: 0.0034
# Epoch 2/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7669e-04 - val_loss: 0.0035
# Epoch 3/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6128e-04 - val_loss: 0.0038
# Epoch 4/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1463e-04 - val_loss: 0.0042
# Epoch 5/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8706e-04 - val_loss: 0.0046
# Epoch 6/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7070e-04 - val_loss: 0.0047
# Epoch 7/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5007e-04 - val_loss: 0.0048
# Epoch 8/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3813e-04 - val_loss: 0.0046
# Epoch 9/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2782e-04 - val_loss: 0.0043
# Epoch 10/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0946e-04 - val_loss: 0.0042
# Epoch 11/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9511e-04 - val_loss: 0.0044
# Epoch 12/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8958e-04 - val_loss: 0.0045
# Epoch 13/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7833e-04 - val_loss: 0.0041
# Epoch 14/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6844e-04 - val_loss: 0.0040
# Epoch 15/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5550e-04 - val_loss: 0.0041
# Epoch 16/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5331e-04 - val_loss: 0.0041
# Epoch 17/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4917e-04 - val_loss: 0.0039
# Epoch 18/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4206e-04 - val_loss: 0.0036
# Epoch 19/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3883e-04 - val_loss: 0.0037
# Epoch 20/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3151e-04 - val_loss: 0.0036
# Epoch 21/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2604e-04 - val_loss: 0.0033
# Epoch 22/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1387e-04 - val_loss: 0.0034
# Epoch 23/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1097e-04 - val_loss: 0.0037
# Epoch 24/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1008e-04 - val_loss: 0.0035
# Epoch 25/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0814e-04 - val_loss: 0.0037
# Epoch 26/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0764e-04 - val_loss: 0.0034
# Epoch 27/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0804e-04 - val_loss: 0.0034
# Epoch 28/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0216e-04 - val_loss: 0.0034
# Epoch 29/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9816e-04 - val_loss: 0.0033
# Epoch 30/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9323e-04 - val_loss: 0.0034
# Epoch 31/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9014e-04 - val_loss: 0.0033
# Epoch 32/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8735e-04 - val_loss: 0.0032
# Epoch 33/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8701e-04 - val_loss: 0.0033
# Epoch 34/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8550e-04 - val_loss: 0.0032
# Epoch 35/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8434e-04 - val_loss: 0.0031
# Epoch 36/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7765e-04 - val_loss: 0.0031
# Epoch 37/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7462e-04 - val_loss: 0.0030
# Epoch 38/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7289e-04 - val_loss: 0.0030
# Epoch 39/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7153e-04 - val_loss: 0.0030
# Epoch 40/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6879e-04 - val_loss: 0.0030
# Epoch 41/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6826e-04 - val_loss: 0.0030
# Epoch 42/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6634e-04 - val_loss: 0.0029
# Epoch 43/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6709e-04 - val_loss: 0.0031
# Epoch 44/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6389e-04 - val_loss: 0.0029
# Epoch 45/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6292e-04 - val_loss: 0.0027
# Epoch 46/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5942e-04 - val_loss: 0.0027
# Epoch 47/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5523e-04 - val_loss: 0.0028
# Epoch 48/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5849e-04 - val_loss: 0.0028
# Epoch 49/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5116e-04 - val_loss: 0.0028
# Epoch 50/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4906e-04 - val_loss: 0.0026
# Epoch 51/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5307e-04 - val_loss: 0.0029
# Epoch 52/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4782e-04 - val_loss: 0.0028
# Epoch 53/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4429e-04 - val_loss: 0.0028
# Epoch 54/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4382e-04 - val_loss: 0.0030
# Epoch 55/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4121e-04 - val_loss: 0.0026
# Epoch 56/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3945e-04 - val_loss: 0.0026
# Epoch 57/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4142e-04 - val_loss: 0.0028
# Epoch 58/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4010e-04 - val_loss: 0.0027
# Epoch 59/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3617e-04 - val_loss: 0.0027
# Epoch 60/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3658e-04 - val_loss: 0.0030
# Epoch 61/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3418e-04 - val_loss: 0.0026
# Epoch 62/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3329e-04 - val_loss: 0.0028
# Epoch 63/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3155e-04 - val_loss: 0.0029
# Epoch 64/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2845e-04 - val_loss: 0.0025
# Epoch 65/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2988e-04 - val_loss: 0.0026
# Epoch 66/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3028e-04 - val_loss: 0.0027
# Epoch 67/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2506e-04 - val_loss: 0.0026
# Epoch 68/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3518e-04 - val_loss: 0.0028
# Epoch 69/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2342e-04 - val_loss: 0.0026
# Epoch 70/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1985e-04 - val_loss: 0.0026
# Epoch 71/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2174e-04 - val_loss: 0.0024
# Epoch 72/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1963e-04 - val_loss: 0.0027
# Epoch 73/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1780e-04 - val_loss: 0.0026
# Epoch 74/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1582e-04 - val_loss: 0.0025
# Epoch 75/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2003e-04 - val_loss: 0.0027
# Epoch 76/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1685e-04 - val_loss: 0.0025
# Epoch 77/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1334e-04 - val_loss: 0.0024
# Epoch 78/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1721e-04 - val_loss: 0.0027
# Epoch 79/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1551e-04 - val_loss: 0.0027
# Epoch 80/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1696e-04 - val_loss: 0.0025
# Epoch 81/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1437e-04 - val_loss: 0.0025
# Epoch 82/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1423e-04 - val_loss: 0.0027
# Epoch 83/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1402e-04 - val_loss: 0.0023
# Epoch 84/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0915e-04 - val_loss: 0.0027
# Epoch 85/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1049e-04 - val_loss: 0.0024
# Epoch 86/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0953e-04 - val_loss: 0.0025
# Epoch 87/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1008e-04 - val_loss: 0.0025
# Epoch 88/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0735e-04 - val_loss: 0.0025
# Epoch 89/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1033e-04 - val_loss: 0.0023
# Epoch 90/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0677e-04 - val_loss: 0.0026
# Epoch 91/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0589e-04 - val_loss: 0.0025
# Epoch 92/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0417e-04 - val_loss: 0.0022
# Epoch 93/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0575e-04 - val_loss: 0.0023
# Epoch 94/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0347e-04 - val_loss: 0.0024
# Epoch 95/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0538e-04 - val_loss: 0.0024
# Epoch 96/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0230e-04 - val_loss: 0.0023
# Epoch 97/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0331e-04 - val_loss: 0.0022
# Epoch 98/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0036e-04 - val_loss: 0.0021
# Epoch 99/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0167e-04 - val_loss: 0.0023
# Epoch 100/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9791e-04 - val_loss: 0.0021
# Epoch 101/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9984e-04 - val_loss: 0.0021
# Epoch 102/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9782e-04 - val_loss: 0.0021
# Epoch 103/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9912e-04 - val_loss: 0.0021
# Epoch 104/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9594e-04 - val_loss: 0.0021
# Epoch 105/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9846e-04 - val_loss: 0.0021
# Epoch 106/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9792e-04 - val_loss: 0.0021
# Epoch 107/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9659e-04 - val_loss: 0.0021
# Epoch 108/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9710e-04 - val_loss: 0.0021
# Epoch 109/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9774e-04 - val_loss: 0.0021
# Epoch 110/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9506e-04 - val_loss: 0.0019
# Epoch 111/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9717e-04 - val_loss: 0.0021
# Epoch 112/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9314e-04 - val_loss: 0.0020
# Epoch 113/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9077e-04 - val_loss: 0.0021
# Epoch 114/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9468e-04 - val_loss: 0.0020
# Epoch 115/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9118e-04 - val_loss: 0.0020
# Epoch 116/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9004e-04 - val_loss: 0.0019
# Epoch 117/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9203e-04 - val_loss: 0.0018
# Epoch 118/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8717e-04 - val_loss: 0.0020
# Epoch 119/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8979e-04 - val_loss: 0.0020
# Epoch 120/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9260e-04 - val_loss: 0.0020
# Epoch 121/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8986e-04 - val_loss: 0.0019
# Epoch 122/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8938e-04 - val_loss: 0.0019
# Epoch 123/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8881e-04 - val_loss: 0.0020
# Epoch 124/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8774e-04 - val_loss: 0.0018
# Epoch 125/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8930e-04 - val_loss: 0.0021
# Epoch 126/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8884e-04 - val_loss: 0.0018
# Epoch 127/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8569e-04 - val_loss: 0.0019
# Epoch 128/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8737e-04 - val_loss: 0.0018
# Epoch 129/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8654e-04 - val_loss: 0.0017
# Epoch 130/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8141e-04 - val_loss: 0.0019
# Epoch 131/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8294e-04 - val_loss: 0.0020
# Epoch 132/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8724e-04 - val_loss: 0.0018
# Epoch 133/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8579e-04 - val_loss: 0.0020
# Epoch 134/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8522e-04 - val_loss: 0.0019
# Epoch 135/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8438e-04 - val_loss: 0.0018
# Epoch 136/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8475e-04 - val_loss: 0.0018
# Epoch 137/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8223e-04 - val_loss: 0.0019
# Epoch 138/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8656e-04 - val_loss: 0.0018
# Epoch 139/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8199e-04 - val_loss: 0.0017
# Epoch 140/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8201e-04 - val_loss: 0.0017
# Epoch 141/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8212e-04 - val_loss: 0.0017
# Epoch 142/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7895e-04 - val_loss: 0.0019
# Epoch 143/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7889e-04 - val_loss: 0.0017
# Epoch 144/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8173e-04 - val_loss: 0.0018
# Epoch 145/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8056e-04 - val_loss: 0.0017
# Epoch 146/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8057e-04 - val_loss: 0.0018
# Epoch 147/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7742e-04 - val_loss: 0.0019
# Epoch 148/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8042e-04 - val_loss: 0.0016
# Epoch 149/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7711e-04 - val_loss: 0.0016
# Epoch 150/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7742e-04 - val_loss: 0.0015
# Epoch 151/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7930e-04 - val_loss: 0.0018
# Epoch 152/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7964e-04 - val_loss: 0.0015
# Epoch 153/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7635e-04 - val_loss: 0.0017
# Epoch 154/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7634e-04 - val_loss: 0.0016
# Epoch 155/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7619e-04 - val_loss: 0.0016
# Epoch 156/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7779e-04 - val_loss: 0.0015
# Epoch 157/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7669e-04 - val_loss: 0.0016
# Epoch 158/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7454e-04 - val_loss: 0.0016
# Epoch 159/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7264e-04 - val_loss: 0.0017
# Epoch 160/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7667e-04 - val_loss: 0.0015
# Epoch 161/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7300e-04 - val_loss: 0.0014
# Epoch 162/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7163e-04 - val_loss: 0.0016
# Epoch 163/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7279e-04 - val_loss: 0.0016
# Epoch 164/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7107e-04 - val_loss: 0.0016
# Epoch 165/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7311e-04 - val_loss: 0.0015
# Epoch 166/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7485e-04 - val_loss: 0.0014
# Epoch 167/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7047e-04 - val_loss: 0.0016
# Epoch 168/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7012e-04 - val_loss: 0.0014
# Epoch 169/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7652e-04 - val_loss: 0.0013
# Epoch 170/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7054e-04 - val_loss: 0.0013
# Epoch 171/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6968e-04 - val_loss: 0.0014
# Epoch 172/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7069e-04 - val_loss: 0.0015
# Epoch 173/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8179e-04 - val_loss: 0.0015
# Epoch 174/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7201e-04 - val_loss: 0.0012
# Epoch 175/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7206e-04 - val_loss: 0.0013
# Epoch 176/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7592e-04 - val_loss: 0.0015
# Epoch 177/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6850e-04 - val_loss: 0.0015
# Epoch 178/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6745e-04 - val_loss: 0.0015
# Epoch 179/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6569e-04 - val_loss: 0.0014
# Epoch 180/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6652e-04 - val_loss: 0.0013
# Epoch 181/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6742e-04 - val_loss: 0.0014
# Epoch 182/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6707e-04 - val_loss: 0.0015
# Epoch 183/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6685e-04 - val_loss: 0.0025
# Epoch 184/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9197e-04 - val_loss: 0.0015
# Epoch 185/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6714e-04 - val_loss: 0.0013
# Epoch 186/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6371e-04 - val_loss: 0.0017
# Epoch 187/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6381e-04 - val_loss: 0.0013
# Epoch 188/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6343e-04 - val_loss: 0.0013
# Epoch 189/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6156e-04 - val_loss: 0.0013
# Epoch 190/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6213e-04 - val_loss: 0.0014
# Epoch 191/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6611e-04 - val_loss: 0.0014
# Epoch 192/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6605e-04 - val_loss: 0.0014
# Epoch 193/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6465e-04 - val_loss: 0.0015
# Epoch 194/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6760e-04 - val_loss: 0.0013
# Epoch 195/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6102e-04 - val_loss: 0.0014
# Epoch 196/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6280e-04 - val_loss: 0.0015
# Epoch 197/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6283e-04 - val_loss: 0.0015
# Epoch 198/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6096e-04 - val_loss: 0.0015
# Epoch 199/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6370e-04 - val_loss: 0.0014
# Epoch 200/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6265e-04 - val_loss: 0.0014
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
# Visualization
plt.figure(figsize=(8, 6))

# Plot actual prices (All data)
plt.plot(df.index[:train_size], df['Price'][:train_size], label='Train', color='blue')

plt.plot(df.index[train_size:], df['Price'][train_size:], label='Test', color='orange')

# Plot predicted prices on the test set
test_data_start = df.index[train_size + n_lookback]  
test_data_end = df.index[-1]
plt.plot(df.index[train_size + n_lookback: len(Y_pred_test) + train_size + n_lookback], Y_pred_test, label='Predict_Test', color='green')


# Plot predicted prices in the future
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:]  # Ngày bắt đầu sau ngày cuối cùng của dữ liệu
plt.plot(future_dates, future_predictions, label='Predict_90days', color='purple')
plt.plot(future_dates[:60], future_predictions[:60], label='Predict_60days', color='blue')
plt.plot(future_dates[:30], future_predictions[:30], label='Predict_30days', color='red')

# plt.title('VCB Stock Price Forecast using LSTM 9:1')
plt.xlabel('Date')
plt.ylabel('Close Price (VND)')
plt.legend()
plt.grid(True)  
plt.show()

# %%
# Create a new dataframe containing dates and future predicted values
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:] 
future_df = pd.DataFrame({'Date': future_dates, 'Forecast': future_predictions.flatten()}) 
future_df.set_index('Date', inplace=True)

# Print the forecast results for the next 90 days
print("Forecast VCB stock prices for the next 90 days:")
print(future_df)
# Out:
# Forecast VCB stock prices for the next 90 days:
#                  Forecast
# Date
# 2024-06-01   90722.476562
# 2024-06-02   92454.351562
# 2024-06-03   94462.718750
# 2024-06-04   96367.210938
# 2024-06-05   98485.328125
# ...                   ...
# 2024-08-25  172994.859375
# 2024-08-26  173946.984375
# 2024-08-27  174945.843750
# 2024-08-28  176000.703125
# 2024-08-29  177127.281250
#
# [90 rows x 1 columns]

# %%
# Calculate RMSE, MAPE, and MAE on the test set
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = mean_absolute_percentage_error(y_true, y_pred) * 100
    mae = mean_absolute_error(y_true, y_pred)
    return rmse, mape, mae

rmse, mape, mae = calculate_metrics(Y_test, Y_pred_test)

print('RMSE:', rmse)
print('MAPE:', mape, '%')
print('MAE:', mae)
# Out:
# RMSE: 3001.917900903312
# MAPE: 3.1602975132478552 %
# MAE: 2809.841370330462

# %% [markdown]
# ## CTG

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None
tf.random.set_seed(0)

# Load data
data = pd.read_csv('../../Dataset/CTG.csv')
df = data[['Date','Close']]
df.rename(columns={'Close': 'Price'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values('Date',inplace=True)
df.set_index('Date',inplace=True)
y = df['Price'].values.reshape(-1, 1)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
y_norm = scaler.fit_transform(y)

# Split data into train and test (90/10)
train_size = int(len(y_norm) * 0.9)
y_train, y_test = y_norm[:train_size], y_norm[train_size:]

# Create input and output sequences
def create_sequences(data, n_lookback, n_forecast):
    X, Y = [], []
    for i in range(n_lookback, len(data) - n_forecast + 1):
        X.append(data[i - n_lookback: i])
        Y.append(data[i: i + n_forecast])
    return np.array(X), np.array(Y)

n_lookback = 60
n_forecast = 1  # Predict time step
X_train, Y_train = create_sequences(y_train, n_lookback, n_forecast)
X_test, Y_test = create_sequences(y_test, n_lookback, n_forecast)

# Build and train the model
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(n_lookback,))) 
model.add(Dense(50, activation='relu'))                          
model.add(Dense(n_forecast))                                      

optimizer = Nadam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error')
model.fit(X_train.reshape(X_train.shape[0], -1), Y_train, epochs=200, validation_data=(X_test, Y_test), batch_size=32, verbose=1)

# Evaluate on the test set
Y_pred_test = model.predict(X_test.reshape(X_test.shape[0], -1))
Y_pred_test = scaler.inverse_transform(Y_pred_test)

# Reshape Y_test before inverse transforming
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))  # Reshape to 2D

# Predict future 30, 60, 90 days
last_sequence = y_norm[-n_lookback:].reshape(1, -1)
future_predictions = []
for i in range(90):
    next_pred = model.predict(last_sequence)
    future_predictions.append(next_pred)
    last_sequence = np.concatenate([last_sequence[:, 1:], next_pred], axis=1)  
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
# Out:
# Epoch 1/200
# c:\Users\ngoct\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0233 - val_loss: 0.0028
# Epoch 2/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 3/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3443e-04 - val_loss: 0.0032
# Epoch 4/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5832e-04 - val_loss: 0.0017
# Epoch 5/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7242e-04 - val_loss: 0.0017
# Epoch 6/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4717e-04 - val_loss: 9.7468e-04
# Epoch 7/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1264e-04 - val_loss: 8.4098e-04
# Epoch 8/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8772e-04 - val_loss: 8.0898e-04
# Epoch 9/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4541e-04 - val_loss: 0.0011
# Epoch 10/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5871e-04 - val_loss: 8.6118e-04
# Epoch 11/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2314e-04 - val_loss: 9.0840e-04
# Epoch 12/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0895e-04 - val_loss: 8.6833e-04
# Epoch 13/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9217e-04 - val_loss: 7.4588e-04
# Epoch 14/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6453e-04 - val_loss: 0.0014
# Epoch 15/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9554e-04 - val_loss: 0.0011
# Epoch 16/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6095e-04 - val_loss: 0.0013
# Epoch 17/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6447e-04 - val_loss: 0.0011
# Epoch 18/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3983e-04 - val_loss: 0.0014
# Epoch 19/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4535e-04 - val_loss: 0.0011
# Epoch 20/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2261e-04 - val_loss: 0.0012
# Epoch 21/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1691e-04 - val_loss: 0.0016
# Epoch 22/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3182e-04 - val_loss: 0.0013
# Epoch 23/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1062e-04 - val_loss: 0.0014
# Epoch 24/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0956e-04 - val_loss: 0.0015
# Epoch 25/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0576e-04 - val_loss: 0.0019
# Epoch 26/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1872e-04 - val_loss: 0.0018
# Epoch 27/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0709e-04 - val_loss: 0.0013
# Epoch 28/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7813e-04 - val_loss: 0.0024
# Epoch 29/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2601e-04 - val_loss: 0.0017
# Epoch 30/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8383e-04 - val_loss: 0.0019
# Epoch 31/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9206e-04 - val_loss: 0.0018
# Epoch 32/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7685e-04 - val_loss: 0.0019
# Epoch 33/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7738e-04 - val_loss: 0.0018
# Epoch 34/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6861e-04 - val_loss: 0.0019
# Epoch 35/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6696e-04 - val_loss: 0.0019
# Epoch 36/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6761e-04 - val_loss: 0.0020
# Epoch 37/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7089e-04 - val_loss: 0.0022
# Epoch 38/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7684e-04 - val_loss: 0.0022
# Epoch 39/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7218e-04 - val_loss: 0.0024
# Epoch 40/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7541e-04 - val_loss: 0.0021
# Epoch 41/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5852e-04 - val_loss: 0.0025
# Epoch 42/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7414e-04 - val_loss: 0.0025
# Epoch 43/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7306e-04 - val_loss: 0.0030
# Epoch 44/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0196e-04 - val_loss: 0.0025
# Epoch 45/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6247e-04 - val_loss: 0.0026
# Epoch 46/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6650e-04 - val_loss: 0.0029
# Epoch 47/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7766e-04 - val_loss: 0.0030
# Epoch 48/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8020e-04 - val_loss: 0.0027
# Epoch 49/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6739e-04 - val_loss: 0.0030
# Epoch 50/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6618e-04 - val_loss: 0.0029
# Epoch 51/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6880e-04 - val_loss: 0.0025
# Epoch 52/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4676e-04 - val_loss: 0.0018
# Epoch 53/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1525e-04 - val_loss: 0.0024
# Epoch 54/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3804e-04 - val_loss: 0.0025
# Epoch 55/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5422e-04 - val_loss: 0.0027
# Epoch 56/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4724e-04 - val_loss: 0.0028
# Epoch 57/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5808e-04 - val_loss: 0.0021
# Epoch 58/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2342e-04 - val_loss: 0.0034
# Epoch 59/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7994e-04 - val_loss: 0.0026
# Epoch 60/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4588e-04 - val_loss: 0.0037
# Epoch 61/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8726e-04 - val_loss: 0.0024
# Epoch 62/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2557e-04 - val_loss: 0.0030
# Epoch 63/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5965e-04 - val_loss: 0.0023
# Epoch 64/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1834e-04 - val_loss: 0.0026
# Epoch 65/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3219e-04 - val_loss: 0.0024
# Epoch 66/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1522e-04 - val_loss: 0.0020
# Epoch 67/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1592e-04 - val_loss: 0.0027
# Epoch 68/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3251e-04 - val_loss: 0.0024
# Epoch 69/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2094e-04 - val_loss: 0.0019
# Epoch 70/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9134e-04 - val_loss: 0.0020
# Epoch 71/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9898e-04 - val_loss: 0.0023
# Epoch 72/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1420e-04 - val_loss: 0.0026
# Epoch 73/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2265e-04 - val_loss: 0.0024
# Epoch 74/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0777e-04 - val_loss: 0.0020
# Epoch 75/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9237e-04 - val_loss: 0.0024
# Epoch 76/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1470e-04 - val_loss: 0.0021
# Epoch 77/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0528e-04 - val_loss: 0.0023
# Epoch 78/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1102e-04 - val_loss: 0.0034
# Epoch 79/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4819e-04 - val_loss: 0.0025
# Epoch 80/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1337e-04 - val_loss: 0.0025
# Epoch 81/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1074e-04 - val_loss: 0.0024
# Epoch 82/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1833e-04 - val_loss: 0.0026
# Epoch 83/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1651e-04 - val_loss: 0.0025
# Epoch 84/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0337e-04 - val_loss: 0.0021
# Epoch 85/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8755e-04 - val_loss: 0.0013
# Epoch 86/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5474e-04 - val_loss: 0.0011
# Epoch 87/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4881e-04 - val_loss: 0.0028
# Epoch 88/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1967e-04 - val_loss: 0.0016
# Epoch 89/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7263e-04 - val_loss: 8.4516e-04
# Epoch 90/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3772e-04 - val_loss: 0.0015
# Epoch 91/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6537e-04 - val_loss: 0.0025
# Epoch 92/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0392e-04 - val_loss: 6.7390e-04
# Epoch 93/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2892e-04 - val_loss: 0.0029
# Epoch 94/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3440e-04 - val_loss: 0.0023
# Epoch 95/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9070e-04 - val_loss: 0.0033
# Epoch 96/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3121e-04 - val_loss: 0.0017
# Epoch 97/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6679e-04 - val_loss: 0.0022
# Epoch 98/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8427e-04 - val_loss: 0.0018
# Epoch 99/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6701e-04 - val_loss: 0.0021
# Epoch 100/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7606e-04 - val_loss: 0.0021
# Epoch 101/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8135e-04 - val_loss: 0.0024
# Epoch 102/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8421e-04 - val_loss: 0.0020
# Epoch 103/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6506e-04 - val_loss: 0.0018
# Epoch 104/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5943e-04 - val_loss: 0.0018
# Epoch 105/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6310e-04 - val_loss: 0.0021
# Epoch 106/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7138e-04 - val_loss: 0.0022
# Epoch 107/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8002e-04 - val_loss: 0.0020
# Epoch 108/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6114e-04 - val_loss: 0.0016
# Epoch 109/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5183e-04 - val_loss: 0.0022
# Epoch 110/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7540e-04 - val_loss: 0.0020
# Epoch 111/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7109e-04 - val_loss: 0.0024
# Epoch 112/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7509e-04 - val_loss: 0.0019
# Epoch 113/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5773e-04 - val_loss: 0.0022
# Epoch 114/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6964e-04 - val_loss: 0.0028
# Epoch 115/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9359e-04 - val_loss: 0.0021
# Epoch 116/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5733e-04 - val_loss: 0.0020
# Epoch 117/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5850e-04 - val_loss: 0.0022
# Epoch 118/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5981e-04 - val_loss: 0.0023
# Epoch 119/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7154e-04 - val_loss: 0.0020
# Epoch 120/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6580e-04 - val_loss: 0.0020
# Epoch 121/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5875e-04 - val_loss: 0.0020
# Epoch 122/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4681e-04 - val_loss: 0.0019
# Epoch 123/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5051e-04 - val_loss: 0.0019
# Epoch 124/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5104e-04 - val_loss: 0.0022
# Epoch 125/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5609e-04 - val_loss: 0.0020
# Epoch 126/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5613e-04 - val_loss: 0.0020
# Epoch 127/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6084e-04 - val_loss: 0.0023
# Epoch 128/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6196e-04 - val_loss: 0.0020
# Epoch 129/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5466e-04 - val_loss: 0.0022
# Epoch 130/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6102e-04 - val_loss: 0.0028
# Epoch 131/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8119e-04 - val_loss: 0.0021
# Epoch 132/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5212e-04 - val_loss: 0.0016
# Epoch 133/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3006e-04 - val_loss: 0.0025
# Epoch 134/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6761e-04 - val_loss: 0.0021
# Epoch 135/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5189e-04 - val_loss: 0.0024
# Epoch 136/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5783e-04 - val_loss: 0.0018
# Epoch 137/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3955e-04 - val_loss: 0.0026
# Epoch 138/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6500e-04 - val_loss: 0.0024
# Epoch 139/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5463e-04 - val_loss: 0.0021
# Epoch 140/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4992e-04 - val_loss: 0.0023
# Epoch 141/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4949e-04 - val_loss: 0.0022
# Epoch 142/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4307e-04 - val_loss: 0.0022
# Epoch 143/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5721e-04 - val_loss: 0.0029
# Epoch 144/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7982e-04 - val_loss: 0.0019
# Epoch 145/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3136e-04 - val_loss: 0.0020
# Epoch 146/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4287e-04 - val_loss: 0.0025
# Epoch 147/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5882e-04 - val_loss: 0.0024
# Epoch 148/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5396e-04 - val_loss: 0.0023
# Epoch 149/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4102e-04 - val_loss: 0.0018
# Epoch 150/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3120e-04 - val_loss: 0.0024
# Epoch 151/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5363e-04 - val_loss: 0.0021
# Epoch 152/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4120e-04 - val_loss: 0.0018
# Epoch 153/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2780e-04 - val_loss: 0.0024
# Epoch 154/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4620e-04 - val_loss: 0.0016
# Epoch 155/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2038e-04 - val_loss: 0.0017
# Epoch 156/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2701e-04 - val_loss: 0.0019
# Epoch 157/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3382e-04 - val_loss: 0.0022
# Epoch 158/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4250e-04 - val_loss: 0.0022
# Epoch 159/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4050e-04 - val_loss: 0.0027
# Epoch 160/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5728e-04 - val_loss: 0.0023
# Epoch 161/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4890e-04 - val_loss: 0.0019
# Epoch 162/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3197e-04 - val_loss: 0.0025
# Epoch 163/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4854e-04 - val_loss: 0.0023
# Epoch 164/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4133e-04 - val_loss: 0.0023
# Epoch 165/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4161e-04 - val_loss: 0.0018
# Epoch 166/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2395e-04 - val_loss: 0.0017
# Epoch 167/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2989e-04 - val_loss: 0.0024
# Epoch 168/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5381e-04 - val_loss: 0.0021
# Epoch 169/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3355e-04 - val_loss: 0.0024
# Epoch 170/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3848e-04 - val_loss: 0.0020
# Epoch 171/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2706e-04 - val_loss: 0.0023
# Epoch 172/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4457e-04 - val_loss: 0.0020
# Epoch 173/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3055e-04 - val_loss: 0.0025
# Epoch 174/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5115e-04 - val_loss: 0.0016
# Epoch 175/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1373e-04 - val_loss: 0.0019
# Epoch 176/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2164e-04 - val_loss: 0.0021
# Epoch 177/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3235e-04 - val_loss: 0.0016
# Epoch 178/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1854e-04 - val_loss: 0.0017
# Epoch 179/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0838e-04 - val_loss: 0.0011
# Epoch 180/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9134e-04 - val_loss: 0.0022
# Epoch 181/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2600e-04 - val_loss: 0.0017
# Epoch 182/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0800e-04 - val_loss: 0.0019
# Epoch 183/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1772e-04 - val_loss: 0.0011
# Epoch 184/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9117e-04 - val_loss: 0.0016
# Epoch 185/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0766e-04 - val_loss: 0.0019
# Epoch 186/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1809e-04 - val_loss: 0.0024
# Epoch 187/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3079e-04 - val_loss: 0.0019
# Epoch 188/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1886e-04 - val_loss: 0.0015
# Epoch 189/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1200e-04 - val_loss: 0.0018
# Epoch 190/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1143e-04 - val_loss: 0.0017
# Epoch 191/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1048e-04 - val_loss: 0.0023
# Epoch 192/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3942e-04 - val_loss: 0.0019
# Epoch 193/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0796e-04 - val_loss: 0.0019
# Epoch 194/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1823e-04 - val_loss: 0.0022
# Epoch 195/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2665e-04 - val_loss: 0.0017
# Epoch 196/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0548e-04 - val_loss: 0.0020
# Epoch 197/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0780e-04 - val_loss: 0.0020
# Epoch 198/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1969e-04 - val_loss: 0.0020
# Epoch 199/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1805e-04 - val_loss: 0.0021
# Epoch 200/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1637e-04 - val_loss: 0.0019
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
# Visualization
plt.figure(figsize=(8, 6))

# Plot actual prices (All data)
plt.plot(df.index[:train_size], df['Price'][:train_size], label='Train', color='blue')

plt.plot(df.index[train_size:], df['Price'][train_size:], label='Test', color='orange')

# Plot predicted prices on the test set
test_data_start = df.index[train_size + n_lookback]  
test_data_end = df.index[-1]
plt.plot(df.index[train_size + n_lookback: len(Y_pred_test) + train_size + n_lookback], Y_pred_test, label='Predict_Test', color='green')


# Plot predicted prices in the future
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:]  # Ngày bắt đầu sau ngày cuối cùng của dữ liệu
plt.plot(future_dates, future_predictions, label='Predict_90days', color='purple')
plt.plot(future_dates[:60], future_predictions[:60], label='Predict_60days', color='blue')
plt.plot(future_dates[:30], future_predictions[:30], label='Predict_30days', color='red')

# plt.title('CTG Stock Price Forecast using MLP 9:1')
plt.xlabel('Date')
plt.ylabel('Close Price (VND)')
plt.legend()
plt.grid(True)  
plt.show()

# %%
# Create a new dataframe containing dates and future predicted values
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:] 
future_df = pd.DataFrame({'Date': future_dates, 'Forecast': future_predictions.flatten()}) 
future_df.set_index('Date', inplace=True)

# Print the forecast results for the next 90 days
print("Forecast VCB stock prices for the next 90 days:")
print(future_df)
# Out:
# Forecast VCB stock prices for the next 90 days:
#                 Forecast
# Date
# 2024-06-01  30432.623047
# 2024-06-02  29809.634766
# 2024-06-03  28612.056641
# 2024-06-04  27953.843750
# 2024-06-05  27056.630859
# ...                  ...
# 2024-08-25  16755.232422
# 2024-08-26  16290.773438
# 2024-08-27  15831.541016
# 2024-08-28  15392.910156
# 2024-08-29  15096.676758
#
# [90 rows x 1 columns]

# %%
# Calculate RMSE, MAPE, and MAE on the test set
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = mean_absolute_percentage_error(y_true, y_pred) * 100
    mae = mean_absolute_error(y_true, y_pred)
    return rmse, mape, mae

rmse, mape, mae = calculate_metrics(Y_test, Y_pred_test)

print('RMSE:', rmse)
print('MAPE:', mape, '%')
print('MAE:', mae)
# Out:
# RMSE: 1225.713555023307
# MAPE: 3.434992875379113 %
# MAE: 1064.4898549107143

# %% [markdown]
# ## BID

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None
tf.random.set_seed(0)

# Load data
data = pd.read_csv('../../Dataset/BID.csv')
df = data[['Date','Close']]
df.rename(columns={'Close': 'Price'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values('Date',inplace=True)
df.set_index('Date',inplace=True)
y = df['Price'].values.reshape(-1, 1)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
y_norm = scaler.fit_transform(y)

# Split data into train and test (90/10)
train_size = int(len(y_norm) * 0.9)
y_train, y_test = y_norm[:train_size], y_norm[train_size:]

# Create input and output sequences
def create_sequences(data, n_lookback, n_forecast):
    X, Y = [], []
    for i in range(n_lookback, len(data) - n_forecast + 1):
        X.append(data[i - n_lookback: i])
        Y.append(data[i: i + n_forecast])
    return np.array(X), np.array(Y)

n_lookback = 60
n_forecast = 1  # Predict time step
X_train, Y_train = create_sequences(y_train, n_lookback, n_forecast)
X_test, Y_test = create_sequences(y_test, n_lookback, n_forecast)

# Build and train the model
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(n_lookback,))) 
model.add(Dense(50, activation='relu'))                            
model.add(Dense(n_forecast))        
                               
optimizer = Nadam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error')
model.fit(X_train.reshape(X_train.shape[0], -1), Y_train, epochs=200, validation_data=(X_test, Y_test), batch_size=32, verbose=1)

# Evaluate on the test set
Y_pred_test = model.predict(X_test.reshape(X_test.shape[0], -1))
Y_pred_test = scaler.inverse_transform(Y_pred_test)

# Reshape Y_test before inverse transforming
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))  # Reshape to 2D

# Predict future 30, 60, 90 days
last_sequence = y_norm[-n_lookback:].reshape(1, -1)
future_predictions = []
for i in range(90):
    next_pred = model.predict(last_sequence)
    future_predictions.append(next_pred)
    last_sequence = np.concatenate([last_sequence[:, 1:], next_pred], axis=1)  
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
# Out:
# Epoch 1/200
# c:\Users\ngoct\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0125 - val_loss: 0.0057
# Epoch 2/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 3/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2626e-04 - val_loss: 0.0018
# Epoch 4/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0910e-04 - val_loss: 0.0011
# Epoch 5/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5972e-04 - val_loss: 7.7596e-04
# Epoch 6/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3572e-04 - val_loss: 6.8464e-04
# Epoch 7/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1957e-04 - val_loss: 7.0686e-04
# Epoch 8/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0551e-04 - val_loss: 7.4952e-04
# Epoch 9/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9585e-04 - val_loss: 7.9834e-04
# Epoch 10/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8470e-04 - val_loss: 8.8120e-04
# Epoch 11/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7580e-04 - val_loss: 9.5680e-04
# Epoch 12/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6612e-04 - val_loss: 0.0010
# Epoch 13/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5903e-04 - val_loss: 0.0011
# Epoch 14/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5049e-04 - val_loss: 0.0011
# Epoch 15/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4340e-04 - val_loss: 0.0012
# Epoch 16/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4269e-04 - val_loss: 0.0013
# Epoch 17/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3486e-04 - val_loss: 0.0013
# Epoch 18/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2920e-04 - val_loss: 0.0014
# Epoch 19/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2364e-04 - val_loss: 0.0015
# Epoch 20/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1827e-04 - val_loss: 0.0015
# Epoch 21/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0895e-04 - val_loss: 0.0014
# Epoch 22/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9856e-04 - val_loss: 0.0015
# Epoch 23/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9707e-04 - val_loss: 0.0016
# Epoch 24/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9602e-04 - val_loss: 0.0017
# Epoch 25/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9648e-04 - val_loss: 0.0019
# Epoch 26/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9457e-04 - val_loss: 0.0020
# Epoch 27/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9258e-04 - val_loss: 0.0021
# Epoch 28/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9147e-04 - val_loss: 0.0022
# Epoch 29/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9321e-04 - val_loss: 0.0023
# Epoch 30/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8627e-04 - val_loss: 0.0024
# Epoch 31/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8467e-04 - val_loss: 0.0024
# Epoch 32/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8177e-04 - val_loss: 0.0027
# Epoch 33/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8630e-04 - val_loss: 0.0025
# Epoch 34/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7721e-04 - val_loss: 0.0026
# Epoch 35/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7629e-04 - val_loss: 0.0028
# Epoch 36/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7790e-04 - val_loss: 0.0026
# Epoch 37/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6899e-04 - val_loss: 0.0027
# Epoch 38/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7021e-04 - val_loss: 0.0028
# Epoch 39/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7366e-04 - val_loss: 0.0027
# Epoch 40/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6359e-04 - val_loss: 0.0028
# Epoch 41/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6507e-04 - val_loss: 0.0028
# Epoch 42/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6178e-04 - val_loss: 0.0029
# Epoch 43/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5959e-04 - val_loss: 0.0027
# Epoch 44/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5228e-04 - val_loss: 0.0034
# Epoch 45/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6965e-04 - val_loss: 0.0032
# Epoch 46/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6000e-04 - val_loss: 0.0031
# Epoch 47/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5447e-04 - val_loss: 0.0032
# Epoch 48/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5568e-04 - val_loss: 0.0033
# Epoch 49/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5482e-04 - val_loss: 0.0031
# Epoch 50/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4704e-04 - val_loss: 0.0031
# Epoch 51/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4303e-04 - val_loss: 0.0030
# Epoch 52/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4237e-04 - val_loss: 0.0031
# Epoch 53/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3965e-04 - val_loss: 0.0030
# Epoch 54/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3679e-04 - val_loss: 0.0031
# Epoch 55/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3671e-04 - val_loss: 0.0030
# Epoch 56/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3279e-04 - val_loss: 0.0031
# Epoch 57/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3478e-04 - val_loss: 0.0032
# Epoch 58/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3625e-04 - val_loss: 0.0030
# Epoch 59/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2928e-04 - val_loss: 0.0031
# Epoch 60/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2967e-04 - val_loss: 0.0029
# Epoch 61/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2281e-04 - val_loss: 0.0030
# Epoch 62/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2612e-04 - val_loss: 0.0032
# Epoch 63/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2992e-04 - val_loss: 0.0030
# Epoch 64/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2078e-04 - val_loss: 0.0032
# Epoch 65/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2849e-04 - val_loss: 0.0030
# Epoch 66/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1871e-04 - val_loss: 0.0033
# Epoch 67/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2461e-04 - val_loss: 0.0032
# Epoch 68/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2410e-04 - val_loss: 0.0031
# Epoch 69/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1538e-04 - val_loss: 0.0034
# Epoch 70/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2302e-04 - val_loss: 0.0031
# Epoch 71/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1392e-04 - val_loss: 0.0030
# Epoch 72/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1222e-04 - val_loss: 0.0030
# Epoch 73/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0893e-04 - val_loss: 0.0030
# Epoch 74/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0808e-04 - val_loss: 0.0034
# Epoch 75/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1878e-04 - val_loss: 0.0028
# Epoch 76/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0216e-04 - val_loss: 0.0029
# Epoch 77/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0633e-04 - val_loss: 0.0028
# Epoch 78/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0097e-04 - val_loss: 0.0036
# Epoch 79/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2130e-04 - val_loss: 0.0029
# Epoch 80/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0419e-04 - val_loss: 0.0036
# Epoch 81/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1865e-04 - val_loss: 0.0038
# Epoch 82/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2610e-04 - val_loss: 0.0033
# Epoch 83/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0734e-04 - val_loss: 0.0034
# Epoch 84/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0913e-04 - val_loss: 0.0025
# Epoch 85/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8445e-04 - val_loss: 0.0036
# Epoch 86/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1217e-04 - val_loss: 0.0045
# Epoch 87/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3216e-04 - val_loss: 0.0027
# Epoch 88/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8969e-04 - val_loss: 0.0027
# Epoch 89/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8921e-04 - val_loss: 0.0039
# Epoch 90/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1974e-04 - val_loss: 0.0031
# Epoch 91/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9801e-04 - val_loss: 0.0028
# Epoch 92/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8868e-04 - val_loss: 0.0035
# Epoch 93/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0696e-04 - val_loss: 0.0029
# Epoch 94/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9082e-04 - val_loss: 0.0035
# Epoch 95/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0423e-04 - val_loss: 0.0027
# Epoch 96/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8364e-04 - val_loss: 0.0031
# Epoch 97/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9591e-04 - val_loss: 0.0032
# Epoch 98/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9464e-04 - val_loss: 0.0035
# Epoch 99/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0319e-04 - val_loss: 0.0030
# Epoch 100/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8978e-04 - val_loss: 0.0031
# Epoch 101/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8891e-04 - val_loss: 0.0033
# Epoch 102/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9318e-04 - val_loss: 0.0032
# Epoch 103/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9266e-04 - val_loss: 0.0033
# Epoch 104/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9453e-04 - val_loss: 0.0032
# Epoch 105/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9015e-04 - val_loss: 0.0027
# Epoch 106/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7661e-04 - val_loss: 0.0035
# Epoch 107/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9389e-04 - val_loss: 0.0030
# Epoch 108/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8455e-04 - val_loss: 0.0036
# Epoch 109/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0050e-04 - val_loss: 0.0032
# Epoch 110/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8908e-04 - val_loss: 0.0027
# Epoch 111/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7988e-04 - val_loss: 0.0034
# Epoch 112/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9503e-04 - val_loss: 0.0033
# Epoch 113/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8877e-04 - val_loss: 0.0033
# Epoch 114/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8835e-04 - val_loss: 0.0031
# Epoch 115/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8872e-04 - val_loss: 0.0031
# Epoch 116/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8242e-04 - val_loss: 0.0031
# Epoch 117/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8232e-04 - val_loss: 0.0029
# Epoch 118/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7843e-04 - val_loss: 0.0033
# Epoch 119/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9064e-04 - val_loss: 0.0035
# Epoch 120/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8670e-04 - val_loss: 0.0034
# Epoch 121/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8635e-04 - val_loss: 0.0030
# Epoch 122/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7767e-04 - val_loss: 0.0031
# Epoch 123/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8110e-04 - val_loss: 0.0032
# Epoch 124/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7967e-04 - val_loss: 0.0032
# Epoch 125/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8063e-04 - val_loss: 0.0032
# Epoch 126/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7919e-04 - val_loss: 0.0031
# Epoch 127/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7770e-04 - val_loss: 0.0032
# Epoch 128/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8049e-04 - val_loss: 0.0031
# Epoch 129/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7725e-04 - val_loss: 0.0032
# Epoch 130/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8077e-04 - val_loss: 0.0031
# Epoch 131/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7637e-04 - val_loss: 0.0030
# Epoch 132/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7188e-04 - val_loss: 0.0028
# Epoch 133/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6925e-04 - val_loss: 0.0031
# Epoch 134/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7588e-04 - val_loss: 0.0029
# Epoch 135/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7224e-04 - val_loss: 0.0029
# Epoch 136/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7056e-04 - val_loss: 0.0028
# Epoch 137/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6650e-04 - val_loss: 0.0032
# Epoch 138/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8340e-04 - val_loss: 0.0029
# Epoch 139/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7067e-04 - val_loss: 0.0028
# Epoch 140/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6498e-04 - val_loss: 0.0028
# Epoch 141/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6771e-04 - val_loss: 0.0030
# Epoch 142/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7460e-04 - val_loss: 0.0029
# Epoch 143/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6932e-04 - val_loss: 0.0028
# Epoch 144/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6644e-04 - val_loss: 0.0026
# Epoch 145/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5852e-04 - val_loss: 0.0027
# Epoch 146/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6794e-04 - val_loss: 0.0026
# Epoch 147/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6234e-04 - val_loss: 0.0025
# Epoch 148/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5937e-04 - val_loss: 0.0032
# Epoch 149/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7058e-04 - val_loss: 0.0027
# Epoch 150/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6364e-04 - val_loss: 0.0026
# Epoch 151/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5991e-04 - val_loss: 0.0029
# Epoch 152/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6622e-04 - val_loss: 0.0023
# Epoch 153/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5206e-04 - val_loss: 0.0026
# Epoch 154/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6197e-04 - val_loss: 0.0025
# Epoch 155/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5509e-04 - val_loss: 0.0029
# Epoch 156/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6523e-04 - val_loss: 0.0025
# Epoch 157/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5303e-04 - val_loss: 0.0026
# Epoch 158/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5584e-04 - val_loss: 0.0024
# Epoch 159/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4836e-04 - val_loss: 0.0028
# Epoch 160/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6351e-04 - val_loss: 0.0027
# Epoch 161/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5480e-04 - val_loss: 0.0029
# Epoch 162/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6727e-04 - val_loss: 0.0024
# Epoch 163/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5236e-04 - val_loss: 0.0018
# Epoch 164/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3892e-04 - val_loss: 0.0024
# Epoch 165/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5541e-04 - val_loss: 0.0022
# Epoch 166/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4768e-04 - val_loss: 0.0023
# Epoch 167/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4915e-04 - val_loss: 0.0027
# Epoch 168/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5944e-04 - val_loss: 0.0023
# Epoch 169/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4961e-04 - val_loss: 0.0021
# Epoch 170/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4385e-04 - val_loss: 0.0024
# Epoch 171/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5008e-04 - val_loss: 0.0021
# Epoch 172/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4391e-04 - val_loss: 0.0027
# Epoch 173/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5729e-04 - val_loss: 0.0021
# Epoch 174/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4294e-04 - val_loss: 0.0022
# Epoch 175/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4742e-04 - val_loss: 0.0022
# Epoch 176/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4462e-04 - val_loss: 0.0019
# Epoch 177/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3902e-04 - val_loss: 0.0020
# Epoch 178/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4065e-04 - val_loss: 0.0022
# Epoch 179/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4599e-04 - val_loss: 0.0026
# Epoch 180/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5241e-04 - val_loss: 0.0016
# Epoch 181/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3248e-04 - val_loss: 0.0019
# Epoch 182/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3916e-04 - val_loss: 0.0019
# Epoch 183/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3785e-04 - val_loss: 0.0019
# Epoch 184/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3695e-04 - val_loss: 0.0020
# Epoch 185/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3826e-04 - val_loss: 0.0024
# Epoch 186/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5279e-04 - val_loss: 0.0016
# Epoch 187/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3032e-04 - val_loss: 0.0018
# Epoch 188/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3545e-04 - val_loss: 0.0021
# Epoch 189/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4301e-04 - val_loss: 0.0018
# Epoch 190/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3271e-04 - val_loss: 0.0023
# Epoch 191/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4501e-04 - val_loss: 0.0023
# Epoch 192/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4717e-04 - val_loss: 0.0021
# Epoch 193/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4096e-04 - val_loss: 0.0015
# Epoch 194/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2547e-04 - val_loss: 0.0022
# Epoch 195/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5010e-04 - val_loss: 0.0023
# Epoch 196/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4972e-04 - val_loss: 0.0018
# Epoch 197/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3491e-04 - val_loss: 0.0020
# Epoch 198/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3942e-04 - val_loss: 0.0022
# Epoch 199/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4408e-04 - val_loss: 0.0022
# Epoch 200/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4482e-04 - val_loss: 0.0018
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
# Visualization
plt.figure(figsize=(8, 6))

# Plot actual prices (All data)
plt.plot(df.index[:train_size], df['Price'][:train_size], label='Train', color='blue')

plt.plot(df.index[train_size:], df['Price'][train_size:], label='Test', color='orange')

# Plot predicted prices on the test set
test_data_start = df.index[train_size + n_lookback]  
test_data_end = df.index[-1]
plt.plot(df.index[train_size + n_lookback: len(Y_pred_test) + train_size + n_lookback], Y_pred_test, label='Predict_Test', color='green')


# Plot predicted prices in the future
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:]  # Ngày bắt đầu sau ngày cuối cùng của dữ liệu
plt.plot(future_dates, future_predictions, label='Predict_90days', color='purple')
plt.plot(future_dates[:60], future_predictions[:60], label='Predict_60days', color='blue')
plt.plot(future_dates[:30], future_predictions[:30], label='Predict_30days', color='red')

# plt.title('VCB Stock Price Forecast using LSTM 7:3')
plt.xlabel('Date')
plt.ylabel('Close Price (VND)')
plt.legend()
plt.grid(True)  
plt.show()

# %%
# Create a new dataframe containing dates and future predicted values
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:] 
future_df = pd.DataFrame({'Date': future_dates, 'Forecast': future_predictions.flatten()}) 
future_df.set_index('Date', inplace=True)

# Print the forecast results for the next 90 days
print("Forecast VCB stock prices for the next 90 days:")
print(future_df)
# Out:
# Forecast VCB stock prices for the next 90 days:
#                 Forecast
# Date
# 2024-06-01  45569.203125
# 2024-06-02  44234.917969
# 2024-06-03  42671.953125
# 2024-06-04  41420.628906
# 2024-06-05  39671.718750
# ...                  ...
# 2024-08-25  17728.990234
# 2024-08-26  17811.179688
# 2024-08-27  17885.664062
# 2024-08-28  17915.220703
# 2024-08-29  17902.724609
#
# [90 rows x 1 columns]

# %%
# Calculate RMSE, MAPE, and MAE on the test set
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = mean_absolute_percentage_error(y_true, y_pred) * 100
    mae = mean_absolute_error(y_true, y_pred)
    return rmse, mape, mae

rmse, mape, mae = calculate_metrics(Y_test, Y_pred_test)

print('RMSE:', rmse)
print('MAPE:', mape, '%')
print('MAE:', mae)
# Out:
# RMSE: 1925.2545694787373
# MAPE: 3.8260167175909277 %
# MAE: 1747.5299553571429
