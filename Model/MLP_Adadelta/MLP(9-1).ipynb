# %% [markdown]
# ## VCB

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None
tf.random.set_seed(0)

# Load data
data = pd.read_csv('../../Dataset/VCB.csv')
df = data[['Date','Close']]
df.rename(columns={'Close': 'Price'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values('Date',inplace=True)
df.set_index('Date',inplace=True)
y = df['Price'].values.reshape(-1, 1)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
y_norm = scaler.fit_transform(y)

# Split data into train and test (90/10)
train_size = int(len(y_norm) * 0.9)
y_train, y_test = y_norm[:train_size], y_norm[train_size:]

# Create input and output sequences
def create_sequences(data, n_lookback, n_forecast):
    X, Y = [], []
    for i in range(n_lookback, len(data) - n_forecast + 1):
        X.append(data[i - n_lookback: i])
        Y.append(data[i: i + n_forecast])
    return np.array(X), np.array(Y)

n_lookback = 60
n_forecast = 1  # Predict time step
X_train, Y_train = create_sequences(y_train, n_lookback, n_forecast)
X_test, Y_test = create_sequences(y_test, n_lookback, n_forecast)

# Build and train the model
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(n_lookback,))) 
model.add(Dense(50, activation='relu'))                            
model.add(Dense(n_forecast))                                       
model.compile(loss='mean_squared_error', optimizer='adadelta')
model.fit(X_train.reshape(X_train.shape[0], -1), Y_train, epochs=200, validation_data=(X_test, Y_test), batch_size=32, verbose=1)

# Evaluate on the test set
Y_pred_test = model.predict(X_test.reshape(X_test.shape[0], -1))
Y_pred_test = scaler.inverse_transform(Y_pred_test)

# Reshape Y_test before inverse transforming
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))  # Reshape to 2D

# Predict future 30, 60, 90 days
last_sequence = y_norm[-n_lookback:].reshape(1, -1)
future_predictions = []
for i in range(90):
    next_pred = model.predict(last_sequence)
    future_predictions.append(next_pred)
    last_sequence = np.concatenate([last_sequence[:, 1:], next_pred], axis=1)  
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
# Out:
# Epoch 1/200
# c:\Users\vanma\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1854 - val_loss: 0.7608
# Epoch 2/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.1645 - val_loss: 0.6724
# Epoch 3/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.1448 - val_loss: 0.5897
# Epoch 4/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.1265 - val_loss: 0.5126
# Epoch 5/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 0.1095 - val_loss: 0.4413
# Epoch 6/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0938 - val_loss: 0.3753
# Epoch 7/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0794 - val_loss: 0.3151
# Epoch 8/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0664 - val_loss: 0.2602
# Epoch 9/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0546 - val_loss: 0.2103
# Epoch 10/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.0440 - val_loss: 0.1656
# Epoch 11/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 0.0346 - val_loss: 0.1264
# Epoch 12/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - loss: 0.0265 - val_loss: 0.0937
# Epoch 13/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 0.0199 - val_loss: 0.0676
# Epoch 14/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.0146 - val_loss: 0.0472
# Epoch 15/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.0105 - val_loss: 0.0319
# Epoch 16/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0074 - val_loss: 0.0207
# Epoch 17/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.0052 - val_loss: 0.0128
# Epoch 18/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 0.0038 - val_loss: 0.0077
# Epoch 19/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 0.0028 - val_loss: 0.0046
# Epoch 20/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 21/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 22/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 23/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 24/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 25/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 26/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 27/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 28/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 29/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 30/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 31/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 32/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 33/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 34/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 35/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 36/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 37/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 38/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 39/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 40/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 41/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 42/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 43/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 44/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 45/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 46/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 47/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 48/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 49/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 50/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 51/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 52/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 53/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 54/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 55/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 56/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 57/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 58/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 59/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 60/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 61/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 62/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 63/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 64/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 9.9316e-04 - val_loss: 0.0010
# Epoch 65/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 9.7898e-04 - val_loss: 9.8712e-04
# Epoch 66/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 9.6594e-04 - val_loss: 9.7510e-04
# Epoch 67/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 9.5418e-04 - val_loss: 9.6567e-04
# Epoch 68/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 9.4331e-04 - val_loss: 9.5826e-04
# Epoch 69/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 9.3325e-04 - val_loss: 9.5162e-04
# Epoch 70/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 9.2397e-04 - val_loss: 9.4598e-04
# Epoch 71/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 9.1561e-04 - val_loss: 9.4095e-04
# Epoch 72/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 9.0793e-04 - val_loss: 9.3629e-04
# Epoch 73/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 9.0086e-04 - val_loss: 9.3197e-04
# Epoch 74/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 8.9426e-04 - val_loss: 9.2787e-04
# Epoch 75/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 8.8802e-04 - val_loss: 9.2398e-04
# Epoch 76/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 8.8223e-04 - val_loss: 9.2033e-04
# Epoch 77/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 8.7687e-04 - val_loss: 9.1680e-04
# Epoch 78/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 8.7169e-04 - val_loss: 9.1339e-04
# Epoch 79/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 8.6672e-04 - val_loss: 9.1010e-04
# Epoch 80/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6195e-04 - val_loss: 9.0692e-04
# Epoch 81/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - loss: 8.5736e-04 - val_loss: 9.0381e-04
# Epoch 82/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 8.5293e-04 - val_loss: 9.0075e-04
# Epoch 83/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 8.4863e-04 - val_loss: 8.9780e-04
# Epoch 84/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 8.4442e-04 - val_loss: 8.9490e-04
# Epoch 85/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 8.4034e-04 - val_loss: 8.9205e-04
# Epoch 86/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 8.3637e-04 - val_loss: 8.8928e-04
# Epoch 87/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 8.3252e-04 - val_loss: 8.8657e-04
# Epoch 88/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 8.2871e-04 - val_loss: 8.8402e-04
# Epoch 89/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 8.2497e-04 - val_loss: 8.8155e-04
# Epoch 90/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 8.2134e-04 - val_loss: 8.7922e-04
# Epoch 91/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 8.1790e-04 - val_loss: 8.7697e-04
# Epoch 92/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 8.1455e-04 - val_loss: 8.7477e-04
# Epoch 93/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 8.1133e-04 - val_loss: 8.7268e-04
# Epoch 94/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 8.0817e-04 - val_loss: 8.7061e-04
# Epoch 95/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 8.0507e-04 - val_loss: 8.6851e-04
# Epoch 96/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 8.0204e-04 - val_loss: 8.6640e-04
# Epoch 97/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 7.9906e-04 - val_loss: 8.6430e-04
# Epoch 98/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 7.9610e-04 - val_loss: 8.6222e-04
# Epoch 99/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 7.9318e-04 - val_loss: 8.6014e-04
# Epoch 100/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 7.9031e-04 - val_loss: 8.5814e-04
# Epoch 101/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 7.8747e-04 - val_loss: 8.5616e-04
# Epoch 102/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 7.8465e-04 - val_loss: 8.5419e-04
# Epoch 103/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 7.8188e-04 - val_loss: 8.5225e-04
# Epoch 104/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 7.7914e-04 - val_loss: 8.5032e-04
# Epoch 105/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 7.7645e-04 - val_loss: 8.4843e-04
# Epoch 106/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 7.7383e-04 - val_loss: 8.4663e-04
# Epoch 107/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 7.7124e-04 - val_loss: 8.4485e-04
# Epoch 108/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 7.6860e-04 - val_loss: 8.4309e-04
# Epoch 109/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 7.6599e-04 - val_loss: 8.4135e-04
# Epoch 110/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - loss: 7.6340e-04 - val_loss: 8.3949e-04
# Epoch 111/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 7.6085e-04 - val_loss: 8.3763e-04
# Epoch 112/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 7.5831e-04 - val_loss: 8.3578e-04
# Epoch 113/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 7.5580e-04 - val_loss: 8.3401e-04
# Epoch 114/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 7.5331e-04 - val_loss: 8.3232e-04
# Epoch 115/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 7.5081e-04 - val_loss: 8.3060e-04
# Epoch 116/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 7.4824e-04 - val_loss: 8.2883e-04
# Epoch 117/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 7.4568e-04 - val_loss: 8.2705e-04
# Epoch 118/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 7.4314e-04 - val_loss: 8.2526e-04
# Epoch 119/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 7.4061e-04 - val_loss: 8.2349e-04
# Epoch 120/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 7.3808e-04 - val_loss: 8.2170e-04
# Epoch 121/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 7.3553e-04 - val_loss: 8.1983e-04
# Epoch 122/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 7.3297e-04 - val_loss: 8.1769e-04
# Epoch 123/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 7.3044e-04 - val_loss: 8.1553e-04
# Epoch 124/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2794e-04 - val_loss: 8.1341e-04
# Epoch 125/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 7.2544e-04 - val_loss: 8.1132e-04
# Epoch 126/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 7.2293e-04 - val_loss: 8.0924e-04
# Epoch 127/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 7.2040e-04 - val_loss: 8.0713e-04
# Epoch 128/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 7.1790e-04 - val_loss: 8.0495e-04
# Epoch 129/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 7.1538e-04 - val_loss: 8.0244e-04
# Epoch 130/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 7.1288e-04 - val_loss: 7.9986e-04
# Epoch 131/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 7.1039e-04 - val_loss: 7.9730e-04
# Epoch 132/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 7.0789e-04 - val_loss: 7.9478e-04
# Epoch 133/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 7.0541e-04 - val_loss: 7.9232e-04
# Epoch 134/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 7.0295e-04 - val_loss: 7.8987e-04
# Epoch 135/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 7.0052e-04 - val_loss: 7.8737e-04
# Epoch 136/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9812e-04 - val_loss: 7.8465e-04
# Epoch 137/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 6.9576e-04 - val_loss: 7.8191e-04
# Epoch 138/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 6.9339e-04 - val_loss: 7.7901e-04
# Epoch 139/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - loss: 6.9106e-04 - val_loss: 7.7608e-04
# Epoch 140/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 6.8874e-04 - val_loss: 7.7310e-04
# Epoch 141/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 6.8641e-04 - val_loss: 7.7014e-04
# Epoch 142/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 6.8405e-04 - val_loss: 7.6705e-04
# Epoch 143/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 6.8171e-04 - val_loss: 7.6406e-04
# Epoch 144/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 6.7937e-04 - val_loss: 7.6118e-04
# Epoch 145/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 6.7704e-04 - val_loss: 7.5837e-04
# Epoch 146/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 6.7475e-04 - val_loss: 7.5546e-04
# Epoch 147/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 6.7247e-04 - val_loss: 7.5225e-04
# Epoch 148/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 6.7022e-04 - val_loss: 7.4888e-04
# Epoch 149/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 6.6797e-04 - val_loss: 7.4547e-04
# Epoch 150/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 6.6568e-04 - val_loss: 7.4218e-04
# Epoch 151/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 6.6339e-04 - val_loss: 7.3894e-04
# Epoch 152/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 6.6117e-04 - val_loss: 7.3560e-04
# Epoch 153/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 6.5898e-04 - val_loss: 7.3220e-04
# Epoch 154/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 6.5683e-04 - val_loss: 7.2895e-04
# Epoch 155/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 6.5469e-04 - val_loss: 7.2567e-04
# Epoch 156/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 6.5251e-04 - val_loss: 7.2215e-04
# Epoch 157/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.5032e-04 - val_loss: 7.1860e-04
# Epoch 158/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 6.4813e-04 - val_loss: 7.1517e-04
# Epoch 159/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 6.4592e-04 - val_loss: 7.1176e-04
# Epoch 160/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 6.4370e-04 - val_loss: 7.0819e-04
# Epoch 161/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 6.4153e-04 - val_loss: 7.0460e-04
# Epoch 162/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 6.3936e-04 - val_loss: 7.0117e-04
# Epoch 163/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 6.3723e-04 - val_loss: 6.9779e-04
# Epoch 164/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 6.3518e-04 - val_loss: 6.9479e-04
# Epoch 165/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 6.3319e-04 - val_loss: 6.9195e-04
# Epoch 166/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 6.3124e-04 - val_loss: 6.8937e-04
# Epoch 167/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 6.2930e-04 - val_loss: 6.8700e-04
# Epoch 168/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - loss: 6.2740e-04 - val_loss: 6.8463e-04
# Epoch 169/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 6.2558e-04 - val_loss: 6.8229e-04
# Epoch 170/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 6.2378e-04 - val_loss: 6.8009e-04
# Epoch 171/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 6.2201e-04 - val_loss: 6.7794e-04
# Epoch 172/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 6.2024e-04 - val_loss: 6.7609e-04
# Epoch 173/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 6.1847e-04 - val_loss: 6.7449e-04
# Epoch 174/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 6.1675e-04 - val_loss: 6.7311e-04
# Epoch 175/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 6.1508e-04 - val_loss: 6.7191e-04
# Epoch 176/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 6.1349e-04 - val_loss: 6.7105e-04
# Epoch 177/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 6.1195e-04 - val_loss: 6.7032e-04
# Epoch 178/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 6.1045e-04 - val_loss: 6.6971e-04
# Epoch 179/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 6.0900e-04 - val_loss: 6.6917e-04
# Epoch 180/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 6.0754e-04 - val_loss: 6.6872e-04
# Epoch 181/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - loss: 6.0611e-04 - val_loss: 6.6835e-04
# Epoch 182/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 6.0472e-04 - val_loss: 6.6800e-04
# Epoch 183/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 6.0337e-04 - val_loss: 6.6767e-04
# Epoch 184/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 6.0205e-04 - val_loss: 6.6735e-04
# Epoch 185/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 6.0075e-04 - val_loss: 6.6703e-04
# Epoch 186/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 5.9947e-04 - val_loss: 6.6676e-04
# Epoch 187/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 5.9820e-04 - val_loss: 6.6651e-04
# Epoch 188/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 5.9695e-04 - val_loss: 6.6614e-04
# Epoch 189/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 5.9573e-04 - val_loss: 6.6579e-04
# Epoch 190/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9452e-04 - val_loss: 6.6546e-04
# Epoch 191/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 5.9334e-04 - val_loss: 6.6517e-04
# Epoch 192/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 5.9218e-04 - val_loss: 6.6488e-04
# Epoch 193/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 5.9103e-04 - val_loss: 6.6459e-04
# Epoch 194/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 5.8990e-04 - val_loss: 6.6430e-04
# Epoch 195/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 5.8878e-04 - val_loss: 6.6402e-04
# Epoch 196/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 5.8767e-04 - val_loss: 6.6373e-04
# Epoch 197/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - loss: 5.8656e-04 - val_loss: 6.6345e-04
# Epoch 198/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 5.8547e-04 - val_loss: 6.6316e-04
# Epoch 199/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 5.8441e-04 - val_loss: 6.6287e-04
# Epoch 200/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 5.8337e-04 - val_loss: 6.6259e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
# Visualization
plt.figure(figsize=(8, 6))

# Plot actual prices (All data)
plt.plot(df.index[:train_size], df['Price'][:train_size], label='Train', color='blue')

plt.plot(df.index[train_size:], df['Price'][train_size:], label='Test', color='orange')

# Plot predicted prices on the test set
test_data_start = df.index[train_size + n_lookback]  
test_data_end = df.index[-1]
plt.plot(df.index[train_size + n_lookback: len(Y_pred_test) + train_size + n_lookback], Y_pred_test, label='Predict_Test', color='green')


# Plot predicted prices in the future
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:]  # Ngày bắt đầu sau ngày cuối cùng của dữ liệu
plt.plot(future_dates, future_predictions, label='Predict_90days', color='purple')
plt.plot(future_dates[:60], future_predictions[:60], label='Predict_60days', color='blue')
plt.plot(future_dates[:30], future_predictions[:30], label='Predict_30days', color='red')

# plt.title('VCB Stock Price Forecast using MLP 9:1')
plt.xlabel('Date')
plt.ylabel('Close Price (VND)')
plt.legend()
plt.grid(True)  
plt.show()

# %%
# Create a new dataframe containing dates and future predicted values
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:] 
future_df = pd.DataFrame({'Date': future_dates, 'Forecast': future_predictions.flatten()}) 
future_df.set_index('Date', inplace=True)

# Print the forecast results for the next 90 days
print("Forecast VCB stock prices for the next 90 days:")
print(future_df)
# Out:
# Forecast VCB stock prices for the next 90 days:
#                 Forecast
# Date
# 2024-06-01  90287.984375
# 2024-06-02  89634.898438
# 2024-06-03  89622.851562
# 2024-06-04  89210.171875
# 2024-06-05  88588.210938
# ...                  ...
# 2024-08-25  92475.539062
# 2024-08-26  92155.351562
# 2024-08-27  92104.281250
# 2024-08-28  93692.906250
# 2024-08-29  93633.343750
#
# [90 rows x 1 columns]

# %%
# Calculate RMSE, MAPE, and MAE on the test set
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = mean_absolute_percentage_error(y_true, y_pred) * 100
    mae = mean_absolute_error(y_true, y_pred)
    return rmse, mape, mae

rmse, mape, mae = calculate_metrics(Y_test, Y_pred_test)

print('RMSE:', rmse)
print('MAPE:', mape, '%')
print('MAE:', mae)
# Out:
# RMSE: 2103.5340728371907
# MAPE: 1.9291954972259706 %
# MAE: 1717.7642331178172

# %% [markdown]
# ## CTG

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None
tf.random.set_seed(0)

# Load data
data = pd.read_csv('../../Dataset/VCB.csv')
df = data[['Date','Close']]
df.rename(columns={'Close': 'Price'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values('Date',inplace=True)
df.set_index('Date',inplace=True)
y = df['Price'].values.reshape(-1, 1)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
y_norm = scaler.fit_transform(y)

# Split data into train and test (90/10)
train_size = int(len(y_norm) * 0.9)
y_train, y_test = y_norm[:train_size], y_norm[train_size:]

# Create input and output sequences
def create_sequences(data, n_lookback, n_forecast):
    X, Y = [], []
    for i in range(n_lookback, len(data) - n_forecast + 1):
        X.append(data[i - n_lookback: i])
        Y.append(data[i: i + n_forecast])
    return np.array(X), np.array(Y)

n_lookback = 60
n_forecast = 1  # Predict time step
X_train, Y_train = create_sequences(y_train, n_lookback, n_forecast)
X_test, Y_test = create_sequences(y_test, n_lookback, n_forecast)

# Build and train the model
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(n_lookback,))) 
model.add(Dense(50, activation='relu'))                            
model.add(Dense(n_forecast))                                       
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train.reshape(X_train.shape[0], -1), Y_train, epochs=200, validation_data=(X_test, Y_test), batch_size=32, verbose=1)

# Evaluate on the test set
Y_pred_test = model.predict(X_test.reshape(X_test.shape[0], -1))
Y_pred_test = scaler.inverse_transform(Y_pred_test)

# Reshape Y_test before inverse transforming
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))  # Reshape to 2D

# Predict future 30, 60, 90 days
last_sequence = y_norm[-n_lookback:].reshape(1, -1)
future_predictions = []
for i in range(90):
    next_pred = model.predict(last_sequence)
    future_predictions.append(next_pred)
    last_sequence = np.concatenate([last_sequence[:, 1:], next_pred], axis=1)  
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
# Out:
# Epoch 1/200
# c:\Users\vanma\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0076 - val_loss: 7.8984e-04
# Epoch 2/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 9.2676e-04 - val_loss: 4.9246e-04
# Epoch 3/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 6.6503e-04 - val_loss: 5.1064e-04
# Epoch 4/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 5.8759e-04 - val_loss: 4.3646e-04
# Epoch 5/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 4.5296e-04 - val_loss: 5.1675e-04
# Epoch 6/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 4.9691e-04 - val_loss: 4.5234e-04
# Epoch 7/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 4.3476e-04 - val_loss: 3.5956e-04
# Epoch 8/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 4.0735e-04 - val_loss: 3.3758e-04
# Epoch 9/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 3.9797e-04 - val_loss: 3.4866e-04
# Epoch 10/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 3.9684e-04 - val_loss: 3.2496e-04
# Epoch 11/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 3.9693e-04 - val_loss: 3.0816e-04
# Epoch 12/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 3.9281e-04 - val_loss: 3.0754e-04
# Epoch 13/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 3.8667e-04 - val_loss: 3.1453e-04
# Epoch 14/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 3.8052e-04 - val_loss: 3.0075e-04
# Epoch 15/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 3.7175e-04 - val_loss: 2.9766e-04
# Epoch 16/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 3.6454e-04 - val_loss: 2.9822e-04
# Epoch 17/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5689e-04 - val_loss: 3.2468e-04
# Epoch 18/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5522e-04 - val_loss: 3.0000e-04
# Epoch 19/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4686e-04 - val_loss: 3.1464e-04
# Epoch 20/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 3.4360e-04 - val_loss: 3.0399e-04
# Epoch 21/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3599e-04 - val_loss: 3.6036e-04
# Epoch 22/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3659e-04 - val_loss: 3.2911e-04
# Epoch 23/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2961e-04 - val_loss: 3.5579e-04
# Epoch 24/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2781e-04 - val_loss: 4.6558e-04
# Epoch 25/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3238e-04 - val_loss: 4.1107e-04
# Epoch 26/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2610e-04 - val_loss: 3.8931e-04
# Epoch 27/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2065e-04 - val_loss: 3.6860e-04
# Epoch 28/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1907e-04 - val_loss: 3.6917e-04
# Epoch 29/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1125e-04 - val_loss: 4.0480e-04
# Epoch 30/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1265e-04 - val_loss: 4.8292e-04
# Epoch 31/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 3.1549e-04 - val_loss: 4.5727e-04
# Epoch 32/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1392e-04 - val_loss: 3.9858e-04
# Epoch 33/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0750e-04 - val_loss: 4.3963e-04
# Epoch 34/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0801e-04 - val_loss: 4.4890e-04
# Epoch 35/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0552e-04 - val_loss: 3.7593e-04
# Epoch 36/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 3.0008e-04 - val_loss: 4.1173e-04
# Epoch 37/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 2.9848e-04 - val_loss: 4.2656e-04
# Epoch 38/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9756e-04 - val_loss: 3.9288e-04
# Epoch 39/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9302e-04 - val_loss: 4.2105e-04
# Epoch 40/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9388e-04 - val_loss: 3.8529e-04
# Epoch 41/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8854e-04 - val_loss: 3.9397e-04
# Epoch 42/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8846e-04 - val_loss: 4.8244e-04
# Epoch 43/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9159e-04 - val_loss: 3.7670e-04
# Epoch 44/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8312e-04 - val_loss: 3.6467e-04
# Epoch 45/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8145e-04 - val_loss: 3.7471e-04
# Epoch 46/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 2.7959e-04 - val_loss: 5.5580e-04
# Epoch 47/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 2.9294e-04 - val_loss: 3.5818e-04
# Epoch 48/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7758e-04 - val_loss: 3.3108e-04
# Epoch 49/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6930e-04 - val_loss: 3.6860e-04
# Epoch 50/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 2.7311e-04 - val_loss: 3.3377e-04
# Epoch 51/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6811e-04 - val_loss: 3.6245e-04
# Epoch 52/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 2.6669e-04 - val_loss: 3.9014e-04
# Epoch 53/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6780e-04 - val_loss: 3.7080e-04
# Epoch 54/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6631e-04 - val_loss: 3.8652e-04
# Epoch 55/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6287e-04 - val_loss: 3.8494e-04
# Epoch 56/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6333e-04 - val_loss: 3.6434e-04
# Epoch 57/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 2.5823e-04 - val_loss: 4.5675e-04
# Epoch 58/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 2.6638e-04 - val_loss: 2.9071e-04
# Epoch 59/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 2.5007e-04 - val_loss: 3.8391e-04
# Epoch 60/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6082e-04 - val_loss: 3.3634e-04
# Epoch 61/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5423e-04 - val_loss: 3.6810e-04
# Epoch 62/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5553e-04 - val_loss: 3.6035e-04
# Epoch 63/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 2.5069e-04 - val_loss: 3.5576e-04
# Epoch 64/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 2.5140e-04 - val_loss: 3.7475e-04
# Epoch 65/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 2.4747e-04 - val_loss: 3.6546e-04
# Epoch 66/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 2.4716e-04 - val_loss: 3.1565e-04
# Epoch 67/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 2.4251e-04 - val_loss: 4.3022e-04
# Epoch 68/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 2.5356e-04 - val_loss: 3.7776e-04
# Epoch 69/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4579e-04 - val_loss: 3.2187e-04
# Epoch 70/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 2.3647e-04 - val_loss: 4.2292e-04
# Epoch 71/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 2.5210e-04 - val_loss: 2.7610e-04
# Epoch 72/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 2.3838e-04 - val_loss: 3.5067e-04
# Epoch 73/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 2.4218e-04 - val_loss: 3.4795e-04
# Epoch 74/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 2.3618e-04 - val_loss: 3.6936e-04
# Epoch 75/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - loss: 2.4206e-04 - val_loss: 3.6458e-04
# Epoch 76/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 2.4248e-04 - val_loss: 3.3887e-04
# Epoch 77/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 2.3764e-04 - val_loss: 3.7863e-04
# Epoch 78/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 2.4108e-04 - val_loss: 2.8828e-04
# Epoch 79/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 2.3587e-04 - val_loss: 2.8823e-04
# Epoch 80/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 2.3170e-04 - val_loss: 2.8828e-04
# Epoch 81/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 2.2999e-04 - val_loss: 2.6906e-04
# Epoch 82/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - loss: 2.2717e-04 - val_loss: 3.1561e-04
# Epoch 83/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 2.3089e-04 - val_loss: 2.6818e-04
# Epoch 84/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 2.2760e-04 - val_loss: 2.8381e-04
# Epoch 85/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 2.2613e-04 - val_loss: 3.1561e-04
# Epoch 86/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 2.1924e-04 - val_loss: 3.3550e-04
# Epoch 87/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 2.2339e-04 - val_loss: 3.0952e-04
# Epoch 88/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 2.2502e-04 - val_loss: 3.2666e-04
# Epoch 89/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 2.2072e-04 - val_loss: 3.3702e-04
# Epoch 90/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 2.2010e-04 - val_loss: 3.3777e-04
# Epoch 91/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 2.2581e-04 - val_loss: 2.8854e-04
# Epoch 92/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 2.2131e-04 - val_loss: 3.3631e-04
# Epoch 93/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 2.1668e-04 - val_loss: 3.6298e-04
# Epoch 94/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 2.1802e-04 - val_loss: 3.3238e-04
# Epoch 95/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 2.2133e-04 - val_loss: 3.1814e-04
# Epoch 96/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 2.2756e-04 - val_loss: 3.4746e-04
# Epoch 97/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 2.1552e-04 - val_loss: 3.5433e-04
# Epoch 98/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 2.1794e-04 - val_loss: 3.6310e-04
# Epoch 99/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 2.2148e-04 - val_loss: 3.3833e-04
# Epoch 100/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 2.2009e-04 - val_loss: 4.1962e-04
# Epoch 101/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - loss: 2.2503e-04 - val_loss: 3.8028e-04
# Epoch 102/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 2.2746e-04 - val_loss: 3.2637e-04
# Epoch 103/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 2.1736e-04 - val_loss: 2.9616e-04
# Epoch 104/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 2.1129e-04 - val_loss: 3.3892e-04
# Epoch 105/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 2.1398e-04 - val_loss: 3.1255e-04
# Epoch 106/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 2.1357e-04 - val_loss: 3.1305e-04
# Epoch 107/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 2.1336e-04 - val_loss: 2.8810e-04
# Epoch 108/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 2.1189e-04 - val_loss: 2.9982e-04
# Epoch 109/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 2.1488e-04 - val_loss: 2.6941e-04
# Epoch 110/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 2.0881e-04 - val_loss: 3.0897e-04
# Epoch 111/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 2.0738e-04 - val_loss: 3.4294e-04
# Epoch 112/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 2.1083e-04 - val_loss: 3.3674e-04
# Epoch 113/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 2.1473e-04 - val_loss: 3.2416e-04
# Epoch 114/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 2.0692e-04 - val_loss: 3.0670e-04
# Epoch 115/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 2.0701e-04 - val_loss: 3.1437e-04
# Epoch 116/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 2.0530e-04 - val_loss: 3.0098e-04
# Epoch 117/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 2.0785e-04 - val_loss: 3.2195e-04
# Epoch 118/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 2.0513e-04 - val_loss: 2.8166e-04
# Epoch 119/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 2.0321e-04 - val_loss: 2.9618e-04
# Epoch 120/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 2.0611e-04 - val_loss: 3.3301e-04
# Epoch 121/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 2.0774e-04 - val_loss: 3.1087e-04
# Epoch 122/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 2.0445e-04 - val_loss: 3.5593e-04
# Epoch 123/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 2.0880e-04 - val_loss: 3.6465e-04
# Epoch 124/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0814e-04 - val_loss: 3.5866e-04
# Epoch 125/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - loss: 1.9847e-04 - val_loss: 3.7432e-04
# Epoch 126/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 2.0412e-04 - val_loss: 2.8495e-04
# Epoch 127/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 1.9726e-04 - val_loss: 3.5092e-04
# Epoch 128/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0501e-04 - val_loss: 3.5601e-04
# Epoch 129/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 2.0225e-04 - val_loss: 3.5463e-04
# Epoch 130/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 1.9682e-04 - val_loss: 3.8230e-04
# Epoch 131/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 2.0976e-04 - val_loss: 3.6291e-04
# Epoch 132/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 2.0820e-04 - val_loss: 4.0222e-04
# Epoch 133/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 2.0647e-04 - val_loss: 4.1752e-04
# Epoch 134/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 2.0459e-04 - val_loss: 5.0761e-04
# Epoch 135/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 2.1272e-04 - val_loss: 4.6861e-04
# Epoch 136/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 1.9879e-04 - val_loss: 4.3746e-04
# Epoch 137/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0423e-04 - val_loss: 3.6241e-04
# Epoch 138/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 1.9145e-04 - val_loss: 3.3074e-04
# Epoch 139/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 1.9236e-04 - val_loss: 3.6274e-04
# Epoch 140/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9946e-04 - val_loss: 3.9890e-04
# Epoch 141/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 1.9917e-04 - val_loss: 4.3633e-04
# Epoch 142/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 1.9899e-04 - val_loss: 3.2736e-04
# Epoch 143/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 1.9558e-04 - val_loss: 4.1655e-04
# Epoch 144/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 1.9443e-04 - val_loss: 5.0946e-04
# Epoch 145/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 2.0107e-04 - val_loss: 4.4918e-04
# Epoch 146/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 1.9707e-04 - val_loss: 4.7559e-04
# Epoch 147/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 1.9723e-04 - val_loss: 4.7289e-04
# Epoch 148/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 1.9747e-04 - val_loss: 5.1170e-04
# Epoch 149/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9733e-04 - val_loss: 4.6770e-04
# Epoch 150/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 1.9639e-04 - val_loss: 5.2680e-04
# Epoch 151/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 1.9741e-04 - val_loss: 5.3081e-04
# Epoch 152/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 1.9879e-04 - val_loss: 5.2111e-04
# Epoch 153/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 1.9688e-04 - val_loss: 4.6285e-04
# Epoch 154/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - loss: 1.9718e-04 - val_loss: 5.0163e-04
# Epoch 155/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 1.9796e-04 - val_loss: 5.7578e-04
# Epoch 156/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 2.0097e-04 - val_loss: 5.6415e-04
# Epoch 157/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 1.9977e-04 - val_loss: 5.2013e-04
# Epoch 158/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 1.9938e-04 - val_loss: 4.9399e-04
# Epoch 159/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 1.9973e-04 - val_loss: 3.9141e-04
# Epoch 160/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9234e-04 - val_loss: 5.8158e-04
# Epoch 161/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 2.0061e-04 - val_loss: 6.2169e-04
# Epoch 162/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 2.0189e-04 - val_loss: 6.1785e-04
# Epoch 163/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 2.0586e-04 - val_loss: 5.4992e-04
# Epoch 164/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9946e-04 - val_loss: 6.3469e-04
# Epoch 165/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 2.0463e-04 - val_loss: 6.1469e-04
# Epoch 166/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0554e-04 - val_loss: 6.4217e-04
# Epoch 167/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 2.0860e-04 - val_loss: 5.8657e-04
# Epoch 168/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 1.9913e-04 - val_loss: 6.1603e-04
# Epoch 169/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0668e-04 - val_loss: 7.0119e-04
# Epoch 170/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 2.0480e-04 - val_loss: 6.0799e-04
# Epoch 171/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 2.0460e-04 - val_loss: 5.9249e-04
# Epoch 172/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 2.0206e-04 - val_loss: 6.1891e-04
# Epoch 173/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 1.9971e-04 - val_loss: 6.8294e-04
# Epoch 174/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0784e-04 - val_loss: 6.8262e-04
# Epoch 175/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 2.0726e-04 - val_loss: 6.4527e-04
# Epoch 176/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 2.0782e-04 - val_loss: 6.0670e-04
# Epoch 177/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 2.0249e-04 - val_loss: 6.7783e-04
# Epoch 178/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 2.0487e-04 - val_loss: 6.4721e-04
# Epoch 179/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 2.0563e-04 - val_loss: 6.8120e-04
# Epoch 180/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 2.1086e-04 - val_loss: 6.4026e-04
# Epoch 181/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 2.0392e-04 - val_loss: 6.8060e-04
# Epoch 182/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 2.0681e-04 - val_loss: 6.2591e-04
# Epoch 183/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 2.0388e-04 - val_loss: 6.4885e-04
# Epoch 184/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0128e-04 - val_loss: 6.2298e-04
# Epoch 185/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0524e-04 - val_loss: 5.9432e-04
# Epoch 186/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 1.9785e-04 - val_loss: 6.6554e-04
# Epoch 187/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 2.0325e-04 - val_loss: 6.6540e-04
# Epoch 188/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0122e-04 - val_loss: 5.6988e-04
# Epoch 189/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9418e-04 - val_loss: 6.5371e-04
# Epoch 190/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 2.0246e-04 - val_loss: 6.1279e-04
# Epoch 191/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 2.0008e-04 - val_loss: 7.1305e-04
# Epoch 192/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 2.0444e-04 - val_loss: 6.5807e-04
# Epoch 193/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 1.9560e-04 - val_loss: 5.8127e-04
# Epoch 194/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 1.9433e-04 - val_loss: 5.9237e-04
# Epoch 195/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 2.0140e-04 - val_loss: 6.1250e-04
# Epoch 196/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9931e-04 - val_loss: 5.8415e-04
# Epoch 197/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 1.9474e-04 - val_loss: 6.3474e-04
# Epoch 198/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 1.9602e-04 - val_loss: 2.8394e-04
# Epoch 199/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 1.7441e-04 - val_loss: 2.8266e-04
# Epoch 200/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 1.8334e-04 - val_loss: 4.3039e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
# Visualization
plt.figure(figsize=(8, 6))

# Plot actual prices (All data)
plt.plot(df.index[:train_size], df['Price'][:train_size], label='Train', color='blue')

plt.plot(df.index[train_size:], df['Price'][train_size:], label='Test', color='orange')

# Plot predicted prices on the test set
test_data_start = df.index[train_size + n_lookback]  
test_data_end = df.index[-1]
plt.plot(df.index[train_size + n_lookback: len(Y_pred_test) + train_size + n_lookback], Y_pred_test, label='Predict_Test', color='green')


# Plot predicted prices in the future
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:]  
plt.plot(future_dates, future_predictions, label='Predict_90days', color='purple')
plt.plot(future_dates[:60], future_predictions[:60], label='Predict_60days', color='blue')
plt.plot(future_dates[:30], future_predictions[:30], label='Predict_30days', color='red')

# plt.title('CTG Stock Price Forecast using MLP 9:1')
plt.xlabel('Date')
plt.ylabel('Close Price (VND)')
plt.legend()
plt.grid(True)  
plt.show()

# %%
# Create a new dataframe containing dates and future predicted values
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:] 
future_df = pd.DataFrame({'Date': future_dates, 'Forecast': future_predictions.flatten()}) 
future_df.set_index('Date', inplace=True)

# Print the forecast results for the next 90 days
print("Forecast VCB stock prices for the next 90 days:")
print(future_df)
# Out:
# Forecast VCB stock prices for the next 90 days:
#                  Forecast
# Date
# 2024-06-01   88767.609375
# 2024-06-02   89283.585938
# 2024-06-03   90390.734375
# 2024-06-04   91159.343750
# 2024-06-05   92170.492188
# ...                   ...
# 2024-08-25  147550.312500
# 2024-08-26  148722.546875
# 2024-08-27  149945.406250
# 2024-08-28  151202.031250
# 2024-08-29  152495.296875
#
# [90 rows x 1 columns]

# %%
# Calculate RMSE, MAPE, and MAE on the test set
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = mean_absolute_percentage_error(y_true, y_pred) * 100
    mae = mean_absolute_error(y_true, y_pred)
    return rmse, mape, mae

rmse, mape, mae = calculate_metrics(Y_test, Y_pred_test)

print('RMSE:', rmse)
print('MAPE:', mape, '%')
print('MAE:', mae)
# Out:
# RMSE: 1695.335736773056
# MAPE: 1.6007865354006678 %
# MAE: 1425.5782596982772

# %% [markdown]
# ## BID

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None
tf.random.set_seed(0)

# Load data
data = pd.read_csv('../../Dataset/BID.csv')
df = data[['Date','Close']]
df.rename(columns={'Close': 'Price'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values('Date',inplace=True)
df.set_index('Date',inplace=True)
y = df['Price'].values.reshape(-1, 1)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
y_norm = scaler.fit_transform(y)

# Split data into train and test (90/10)
train_size = int(len(y_norm) * 0.9)
y_train, y_test = y_norm[:train_size], y_norm[train_size:]

# Create input and output sequences
def create_sequences(data, n_lookback, n_forecast):
    X, Y = [], []
    for i in range(n_lookback, len(data) - n_forecast + 1):
        X.append(data[i - n_lookback: i])
        Y.append(data[i: i + n_forecast])
    return np.array(X), np.array(Y)

n_lookback = 60
n_forecast = 1  # Predict time step
X_train, Y_train = create_sequences(y_train, n_lookback, n_forecast)
X_test, Y_test = create_sequences(y_test, n_lookback, n_forecast)

# Build and train the model
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(n_lookback,))) 
model.add(Dense(50, activation='relu'))                            
model.add(Dense(n_forecast))                                       
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train.reshape(X_train.shape[0], -1), Y_train, epochs=200, validation_data=(X_test, Y_test), batch_size=32, verbose=1)

# Evaluate on the test set
Y_pred_test = model.predict(X_test.reshape(X_test.shape[0], -1))
Y_pred_test = scaler.inverse_transform(Y_pred_test)

# Reshape Y_test before inverse transforming
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))  # Reshape to 2D

# Predict future 30, 60, 90 days
last_sequence = y_norm[-n_lookback:].reshape(1, -1)
future_predictions = []
for i in range(90):
    next_pred = model.predict(last_sequence)
    future_predictions.append(next_pred)
    last_sequence = np.concatenate([last_sequence[:, 1:], next_pred], axis=1)  
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
# Out:
# Epoch 1/200
# c:\Users\vanma\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0800 - val_loss: 0.0044
# Epoch 2/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 3/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 9.4167e-04 - val_loss: 0.0010
# Epoch 4/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 7.6646e-04 - val_loss: 9.0857e-04
# Epoch 5/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 6.6195e-04 - val_loss: 8.1348e-04
# Epoch 6/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 5.9412e-04 - val_loss: 7.5516e-04
# Epoch 7/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 5.6000e-04 - val_loss: 7.1331e-04
# Epoch 8/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 5.3341e-04 - val_loss: 6.8755e-04
# Epoch 9/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 5.1341e-04 - val_loss: 6.9570e-04
# Epoch 10/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 5.0060e-04 - val_loss: 7.2385e-04
# Epoch 11/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 4.9259e-04 - val_loss: 7.6788e-04
# Epoch 12/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 4.8005e-04 - val_loss: 7.9790e-04
# Epoch 13/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 4.5997e-04 - val_loss: 8.5188e-04
# Epoch 14/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 4.3569e-04 - val_loss: 8.4858e-04
# Epoch 15/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 4.0333e-04 - val_loss: 8.2003e-04
# Epoch 16/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 3.7592e-04 - val_loss: 6.9957e-04
# Epoch 17/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 3.5252e-04 - val_loss: 5.9012e-04
# Epoch 18/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 3.4678e-04 - val_loss: 5.5168e-04
# Epoch 19/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 3.5120e-04 - val_loss: 6.1626e-04
# Epoch 20/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 3.6606e-04 - val_loss: 7.4419e-04
# Epoch 21/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 3.7640e-04 - val_loss: 8.9073e-04
# Epoch 22/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 3.7961e-04 - val_loss: 0.0010
# Epoch 23/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 3.8055e-04 - val_loss: 0.0011
# Epoch 24/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7961e-04 - val_loss: 0.0013
# Epoch 25/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 3.8421e-04 - val_loss: 0.0014
# Epoch 26/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 3.8835e-04 - val_loss: 0.0016
# Epoch 27/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 3.8401e-04 - val_loss: 0.0017
# Epoch 28/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 3.7905e-04 - val_loss: 0.0018
# Epoch 29/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 3.7164e-04 - val_loss: 0.0018
# Epoch 30/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 3.6312e-04 - val_loss: 0.0017
# Epoch 31/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 3.5533e-04 - val_loss: 0.0017
# Epoch 32/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 3.5176e-04 - val_loss: 0.0016
# Epoch 33/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 3.4721e-04 - val_loss: 0.0016
# Epoch 34/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 3.4678e-04 - val_loss: 0.0017
# Epoch 35/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 3.5104e-04 - val_loss: 0.0017
# Epoch 36/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 3.4906e-04 - val_loss: 0.0018
# Epoch 37/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 3.5811e-04 - val_loss: 0.0018
# Epoch 38/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - loss: 3.5878e-04 - val_loss: 0.0019
# Epoch 39/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 3.5775e-04 - val_loss: 0.0019
# Epoch 40/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 3.5761e-04 - val_loss: 0.0019
# Epoch 41/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 3.5562e-04 - val_loss: 0.0019
# Epoch 42/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 3.5584e-04 - val_loss: 0.0019
# Epoch 43/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 3.5281e-04 - val_loss: 0.0019
# Epoch 44/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 3.5355e-04 - val_loss: 0.0020
# Epoch 45/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 3.5771e-04 - val_loss: 0.0020
# Epoch 46/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 3.5768e-04 - val_loss: 0.0020
# Epoch 47/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 3.5311e-04 - val_loss: 0.0020
# Epoch 48/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 3.4883e-04 - val_loss: 0.0019
# Epoch 49/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 3.4392e-04 - val_loss: 0.0020
# Epoch 50/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 3.4922e-04 - val_loss: 0.0020
# Epoch 51/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 3.4995e-04 - val_loss: 0.0021
# Epoch 52/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 3.4865e-04 - val_loss: 0.0020
# Epoch 53/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 3.4619e-04 - val_loss: 0.0020
# Epoch 54/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 3.3961e-04 - val_loss: 0.0021
# Epoch 55/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 3.4180e-04 - val_loss: 0.0020
# Epoch 56/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 3.3677e-04 - val_loss: 0.0021
# Epoch 57/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 3.4152e-04 - val_loss: 0.0021
# Epoch 58/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 3.3546e-04 - val_loss: 0.0021
# Epoch 59/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 3.3591e-04 - val_loss: 0.0021
# Epoch 60/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 3.3797e-04 - val_loss: 0.0020
# Epoch 61/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 3.3230e-04 - val_loss: 0.0021
# Epoch 62/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 3.3193e-04 - val_loss: 0.0021
# Epoch 63/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 3.3340e-04 - val_loss: 0.0021
# Epoch 64/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 3.3282e-04 - val_loss: 0.0021
# Epoch 65/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 3.3028e-04 - val_loss: 0.0021
# Epoch 66/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 3.3027e-04 - val_loss: 0.0021
# Epoch 67/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 3.2302e-04 - val_loss: 0.0022
# Epoch 68/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 3.3412e-04 - val_loss: 0.0021
# Epoch 69/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 3.2788e-04 - val_loss: 0.0021
# Epoch 70/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 3.2539e-04 - val_loss: 0.0022
# Epoch 71/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 3.3284e-04 - val_loss: 0.0022
# Epoch 72/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 3.2810e-04 - val_loss: 0.0022
# Epoch 73/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 3.3320e-04 - val_loss: 0.0022
# Epoch 74/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3095e-04 - val_loss: 0.0022
# Epoch 75/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 3.2782e-04 - val_loss: 0.0021
# Epoch 76/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 3.1977e-04 - val_loss: 0.0022
# Epoch 77/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 3.2757e-04 - val_loss: 0.0022
# Epoch 78/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 3.2406e-04 - val_loss: 0.0022
# Epoch 79/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2626e-04 - val_loss: 0.0022
# Epoch 80/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2489e-04 - val_loss: 0.0022
# Epoch 81/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 3.2148e-04 - val_loss: 0.0021
# Epoch 82/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 3.2167e-04 - val_loss: 0.0022
# Epoch 83/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 3.2894e-04 - val_loss: 0.0022
# Epoch 84/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 3.2444e-04 - val_loss: 0.0020
# Epoch 85/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 3.1400e-04 - val_loss: 0.0022
# Epoch 86/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 3.2473e-04 - val_loss: 0.0021
# Epoch 87/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 3.2048e-04 - val_loss: 0.0022
# Epoch 88/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 3.1616e-04 - val_loss: 0.0020
# Epoch 89/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 3.1034e-04 - val_loss: 0.0022
# Epoch 90/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 3.1713e-04 - val_loss: 0.0021
# Epoch 91/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 3.1032e-04 - val_loss: 0.0019
# Epoch 92/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 3.0192e-04 - val_loss: 0.0020
# Epoch 93/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 3.1712e-04 - val_loss: 0.0020
# Epoch 94/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - loss: 3.0797e-04 - val_loss: 0.0020
# Epoch 95/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 3.0971e-04 - val_loss: 0.0020
# Epoch 96/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 3.0414e-04 - val_loss: 0.0019
# Epoch 97/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 3.0069e-04 - val_loss: 0.0019
# Epoch 98/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 3.0690e-04 - val_loss: 0.0021
# Epoch 99/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 3.1099e-04 - val_loss: 0.0020
# Epoch 100/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 3.0995e-04 - val_loss: 0.0019
# Epoch 101/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 2.9250e-04 - val_loss: 0.0021
# Epoch 102/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 3.0952e-04 - val_loss: 0.0018
# Epoch 103/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 2.8880e-04 - val_loss: 0.0020
# Epoch 104/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 3.0077e-04 - val_loss: 0.0019
# Epoch 105/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 2.9741e-04 - val_loss: 0.0020
# Epoch 106/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0008e-04 - val_loss: 0.0019
# Epoch 107/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0279e-04 - val_loss: 0.0020
# Epoch 108/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 2.9959e-04 - val_loss: 0.0017
# Epoch 109/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 2.8674e-04 - val_loss: 0.0020
# Epoch 110/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0024e-04 - val_loss: 0.0018
# Epoch 111/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 2.8265e-04 - val_loss: 0.0019
# Epoch 112/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 2.9400e-04 - val_loss: 0.0018
# Epoch 113/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 2.8128e-04 - val_loss: 0.0019
# Epoch 114/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 2.9394e-04 - val_loss: 0.0018
# Epoch 115/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 2.8304e-04 - val_loss: 0.0022
# Epoch 116/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 3.1058e-04 - val_loss: 0.0019
# Epoch 117/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 2.9004e-04 - val_loss: 0.0020
# Epoch 118/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 2.9154e-04 - val_loss: 0.0021
# Epoch 119/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 2.9789e-04 - val_loss: 0.0019
# Epoch 120/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - loss: 2.8657e-04 - val_loss: 0.0021
# Epoch 121/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 2.9582e-04 - val_loss: 0.0019
# Epoch 122/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 2.8886e-04 - val_loss: 0.0020
# Epoch 123/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9097e-04 - val_loss: 0.0021
# Epoch 124/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - loss: 3.0359e-04 - val_loss: 0.0022
# Epoch 125/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - loss: 3.1158e-04 - val_loss: 0.0020
# Epoch 126/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 2.9491e-04 - val_loss: 0.0021
# Epoch 127/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 3.1442e-04 - val_loss: 0.0024
# Epoch 128/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 3.3781e-04 - val_loss: 0.0021
# Epoch 129/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 3.3813e-04 - val_loss: 0.0023
# Epoch 130/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 3.5041e-04 - val_loss: 0.0020
# Epoch 131/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 3.4926e-04 - val_loss: 0.0019
# Epoch 132/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 3.5121e-04 - val_loss: 0.0016
# Epoch 133/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - loss: 3.4263e-04 - val_loss: 0.0015
# Epoch 134/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 3.3571e-04 - val_loss: 0.0012
# Epoch 135/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 3.4447e-04 - val_loss: 0.0013
# Epoch 136/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 3.2027e-04 - val_loss: 0.0013
# Epoch 137/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 3.4700e-04 - val_loss: 9.4642e-04
# Epoch 138/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 3.0160e-04 - val_loss: 0.0010
# Epoch 139/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 3.2387e-04 - val_loss: 0.0012
# Epoch 140/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - loss: 3.3176e-04 - val_loss: 9.4166e-04
# Epoch 141/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 3.2295e-04 - val_loss: 8.8850e-04
# Epoch 142/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 3.2023e-04 - val_loss: 9.3046e-04
# Epoch 143/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 3.4772e-04 - val_loss: 6.7153e-04
# Epoch 144/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 3.2890e-04 - val_loss: 4.8165e-04
# Epoch 145/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 2.9552e-04 - val_loss: 5.4347e-04
# Epoch 146/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 3.0122e-04 - val_loss: 4.6183e-04
# Epoch 147/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8682e-04 - val_loss: 3.9221e-04
# Epoch 148/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7113e-04 - val_loss: 4.0743e-04
# Epoch 149/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6119e-04 - val_loss: 5.2580e-04
# Epoch 150/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 2.7952e-04 - val_loss: 4.0176e-04
# Epoch 151/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 2.5491e-04 - val_loss: 5.3860e-04
# Epoch 152/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 2.7727e-04 - val_loss: 4.2066e-04
# Epoch 153/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 2.5740e-04 - val_loss: 3.9795e-04
# Epoch 154/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 2.4986e-04 - val_loss: 3.9937e-04
# Epoch 155/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 2.6867e-04 - val_loss: 4.3653e-04
# Epoch 156/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 2.6128e-04 - val_loss: 4.2045e-04
# Epoch 157/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5281e-04 - val_loss: 3.8710e-04
# Epoch 158/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4328e-04 - val_loss: 4.1779e-04
# Epoch 159/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 2.4536e-04 - val_loss: 4.4343e-04
# Epoch 160/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 2.5078e-04 - val_loss: 3.9955e-04
# Epoch 161/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 2.5126e-04 - val_loss: 4.7660e-04
# Epoch 162/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5380e-04 - val_loss: 4.3342e-04
# Epoch 163/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 2.4907e-04 - val_loss: 4.8466e-04
# Epoch 164/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - loss: 2.5306e-04 - val_loss: 4.5826e-04
# Epoch 165/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 2.4548e-04 - val_loss: 4.7442e-04
# Epoch 166/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 2.5367e-04 - val_loss: 4.6247e-04
# Epoch 167/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 2.5027e-04 - val_loss: 4.5712e-04
# Epoch 168/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 2.4582e-04 - val_loss: 5.5076e-04
# Epoch 169/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 2.6420e-04 - val_loss: 4.7586e-04
# Epoch 170/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 2.5307e-04 - val_loss: 5.5349e-04
# Epoch 171/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 2.6143e-04 - val_loss: 4.8303e-04
# Epoch 172/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 2.6987e-04 - val_loss: 4.2690e-04
# Epoch 173/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - loss: 2.4264e-04 - val_loss: 6.9133e-04
# Epoch 174/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - loss: 2.7557e-04 - val_loss: 4.2762e-04
# Epoch 175/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 2.4591e-04 - val_loss: 4.4375e-04
# Epoch 176/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 2.5831e-04 - val_loss: 3.9056e-04
# Epoch 177/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 2.5439e-04 - val_loss: 3.8580e-04
# Epoch 178/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 2.3811e-04 - val_loss: 3.9503e-04
# Epoch 179/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 2.3069e-04 - val_loss: 4.7385e-04
# Epoch 180/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 2.4586e-04 - val_loss: 3.7705e-04
# Epoch 181/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 2.4266e-04 - val_loss: 3.9639e-04
# Epoch 182/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - loss: 2.3480e-04 - val_loss: 3.5638e-04
# Epoch 183/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 2.2912e-04 - val_loss: 3.5243e-04
# Epoch 184/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 2.2119e-04 - val_loss: 4.3467e-04
# Epoch 185/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 2.3900e-04 - val_loss: 3.7663e-04
# Epoch 186/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3669e-04 - val_loss: 3.9262e-04
# Epoch 187/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 2.3576e-04 - val_loss: 4.3307e-04
# Epoch 188/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 2.3779e-04 - val_loss: 3.5056e-04
# Epoch 189/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 2.1977e-04 - val_loss: 5.0373e-04
# Epoch 190/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 2.3688e-04 - val_loss: 4.1244e-04
# Epoch 191/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 2.3368e-04 - val_loss: 3.7329e-04
# Epoch 192/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 2.3135e-04 - val_loss: 3.4450e-04
# Epoch 193/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 2.1735e-04 - val_loss: 4.2632e-04
# Epoch 194/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - loss: 2.2775e-04 - val_loss: 4.1091e-04
# Epoch 195/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4086e-04 - val_loss: 4.3138e-04
# Epoch 196/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2920e-04 - val_loss: 4.1472e-04
# Epoch 197/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3704e-04 - val_loss: 3.7752e-04
# Epoch 198/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 2.2712e-04 - val_loss: 5.6256e-04
# Epoch 199/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 2.3981e-04 - val_loss: 5.0916e-04
# Epoch 200/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 2.4279e-04 - val_loss: 5.0402e-04
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
# Visualization
plt.figure(figsize=(8, 6))

# Plot actual prices (All data)
plt.plot(df.index[:train_size], df['Price'][:train_size], label='Train', color='blue')

plt.plot(df.index[train_size:], df['Price'][train_size:], label='Test', color='orange')

# Plot predicted prices on the test set
test_data_start = df.index[train_size + n_lookback]  
test_data_end = df.index[-1]
plt.plot(df.index[train_size + n_lookback: len(Y_pred_test) + train_size + n_lookback], Y_pred_test, label='Predict_Test', color='green')


# Plot predicted prices in the future
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:]  # Ngày bắt đầu sau ngày cuối cùng của dữ liệu
plt.plot(future_dates, future_predictions, label='Predict_90days', color='purple')
plt.plot(future_dates[:60], future_predictions[:60], label='Predict_60days', color='blue')
plt.plot(future_dates[:30], future_predictions[:30], label='Predict_30days', color='red')

# plt.title('BID Stock Price Forecast using MLP 9:1')
plt.xlabel('Date')
plt.ylabel('Close Price (VND)')
plt.legend()
plt.grid(True)  
plt.show()

# %%
# Create a new dataframe containing dates and future predicted values
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:] 
future_df = pd.DataFrame({'Date': future_dates, 'Forecast': future_predictions.flatten()}) 
future_df.set_index('Date', inplace=True)

# Print the forecast results for the next 90 days
print("Forecast VCB stock prices for the next 90 days:")
print(future_df)
# Out:
# Forecast VCB stock prices for the next 90 days:
#                 Forecast
# Date
# 2024-06-01  46772.187500
# 2024-06-02  46419.906250
# 2024-06-03  45980.132812
# 2024-06-04  45635.996094
# 2024-06-05  44704.886719
# ...                  ...
# 2024-08-25  31008.730469
# 2024-08-26  30811.667969
# 2024-08-27  30640.878906
# 2024-08-28  30450.552734
# 2024-08-29  30273.484375
#
# [90 rows x 1 columns]

# %%
# Calculate RMSE, MAPE, and MAE on the test set
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = mean_absolute_percentage_error(y_true, y_pred) * 100
    mae = mean_absolute_error(y_true, y_pred)
    return rmse, mape, mae

rmse, mape, mae = calculate_metrics(Y_test, Y_pred_test)

print('RMSE:', rmse)
print('MAPE:', mape, '%')
print('MAE:', mae)
# Out:
# RMSE: 1016.9670900450805
# MAPE: 1.6621152325456432 %
# MAE: 760.3416517857142
