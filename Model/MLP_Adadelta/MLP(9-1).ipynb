# %% [markdown]
# ## VCB

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None
tf.random.set_seed(0)

# Load data
data = pd.read_csv('../../Dataset/VCB.csv')
df = data[['Date','Close']]
df.rename(columns={'Close': 'Price'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values('Date',inplace=True)
df.set_index('Date',inplace=True)
y = df['Price'].values.reshape(-1, 1)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
y_norm = scaler.fit_transform(y)

# Split data into train and test (90/10)
train_size = int(len(y_norm) * 0.9)
y_train, y_test = y_norm[:train_size], y_norm[train_size:]

# Create input and output sequences
def create_sequences(data, n_lookback, n_forecast):
    X, Y = [], []
    for i in range(n_lookback, len(data) - n_forecast + 1):
        X.append(data[i - n_lookback: i])
        Y.append(data[i: i + n_forecast])
    return np.array(X), np.array(Y)

n_lookback = 60
n_forecast = 1  # Predict time step
X_train, Y_train = create_sequences(y_train, n_lookback, n_forecast)
X_test, Y_test = create_sequences(y_test, n_lookback, n_forecast)

# Build and train the model
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(n_lookback,))) 
model.add(Dense(50, activation='relu'))                            
model.add(Dense(n_forecast))                                       
model.compile(loss='mean_squared_error', optimizer='adadelta')
model.fit(X_train.reshape(X_train.shape[0], -1), Y_train, epochs=200, validation_data=(X_test, Y_test), batch_size=32, verbose=1)

# Evaluate on the test set
Y_pred_test = model.predict(X_test.reshape(X_test.shape[0], -1))
Y_pred_test = scaler.inverse_transform(Y_pred_test)

# Reshape Y_test before inverse transforming
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))  # Reshape to 2D

# Predict future 30, 60, 90 days
last_sequence = y_norm[-n_lookback:].reshape(1, -1)
future_predictions = []
for i in range(90):
    next_pred = model.predict(last_sequence)
    future_predictions.append(next_pred)
    last_sequence = np.concatenate([last_sequence[:, 1:], next_pred], axis=1)  
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
# Out:
# Epoch 1/200
# c:\Users\vanma\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.1796 - val_loss: 5.0478
# Epoch 2/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 1.1125 - val_loss: 4.7493
# Epoch 3/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 1.0453 - val_loss: 4.4515
# Epoch 4/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.9784 - val_loss: 4.1575
# Epoch 5/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 0.9125 - val_loss: 3.8699
# Epoch 6/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.8482 - val_loss: 3.5901
# Epoch 7/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.7857 - val_loss: 3.3188
# Epoch 8/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 0.7252 - val_loss: 3.0566
# Epoch 9/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.6669 - val_loss: 2.8041
# Epoch 10/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.6109 - val_loss: 2.5619
# Epoch 11/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 0.5573 - val_loss: 2.3304
# Epoch 12/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.5062 - val_loss: 2.1103
# Epoch 13/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 0.4577 - val_loss: 1.9021
# Epoch 14/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4120 - val_loss: 1.7064
# Epoch 15/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 0.3691 - val_loss: 1.5230
# Epoch 16/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 0.3289 - val_loss: 1.3520
# Epoch 17/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.2914 - val_loss: 1.1933
# Epoch 18/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.2566 - val_loss: 1.0466
# Epoch 19/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.2245 - val_loss: 0.9118
# Epoch 20/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 0.1951 - val_loss: 0.7886
# Epoch 21/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.1683 - val_loss: 0.6767
# Epoch 22/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.1441 - val_loss: 0.5757
# Epoch 23/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.1223 - val_loss: 0.4856
# Epoch 24/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.1029 - val_loss: 0.4060
# Epoch 25/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 0.0858 - val_loss: 0.3362
# Epoch 26/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 0.0708 - val_loss: 0.2752
# Epoch 27/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 0.0577 - val_loss: 0.2223
# Epoch 28/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0464 - val_loss: 0.1770
# Epoch 29/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 0.0369 - val_loss: 0.1386
# Epoch 30/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.0289 - val_loss: 0.1066
# Epoch 31/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0223 - val_loss: 0.0802
# Epoch 32/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 0.0170 - val_loss: 0.0589
# Epoch 33/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0127 - val_loss: 0.0420
# Epoch 34/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0095 - val_loss: 0.0291
# Epoch 35/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0070 - val_loss: 0.0195
# Epoch 36/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0053 - val_loss: 0.0127
# Epoch 37/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0041 - val_loss: 0.0081
# Epoch 38/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 0.0034 - val_loss: 0.0053
# Epoch 39/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 0.0030 - val_loss: 0.0038
# Epoch 40/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 41/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 42/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 43/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 44/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 45/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 46/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 47/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 48/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 49/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 50/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 51/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 52/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 53/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 54/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 55/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 56/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 57/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 58/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 59/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 60/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 61/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 62/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 63/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 64/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 65/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 66/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 67/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 68/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 69/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 70/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 71/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 72/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 73/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 74/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 75/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 76/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 77/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 78/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 79/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 80/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 81/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 82/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 83/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 84/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 85/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 86/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 87/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 88/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 89/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 90/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 91/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 92/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 93/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 94/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 95/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 96/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 97/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 98/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 99/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 100/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 101/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 102/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 103/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 104/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 105/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 106/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 107/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 108/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 109/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 110/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 111/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 112/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 113/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 114/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 115/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 116/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 117/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 118/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 119/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 120/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 121/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 122/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 123/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 124/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 125/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 126/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 127/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 128/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 129/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 130/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 131/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 132/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 133/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 134/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 135/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 136/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 137/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 138/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 139/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 140/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 141/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 142/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 143/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 144/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 145/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 146/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 147/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 148/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 149/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 150/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 151/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 152/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 153/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 154/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 155/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 156/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 157/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 158/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 159/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 160/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 161/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 162/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 163/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 164/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 165/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 166/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 167/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 168/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 169/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 170/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 171/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 172/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 173/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 174/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 175/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 176/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 177/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 178/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 179/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 180/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 181/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 182/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 183/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 184/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 185/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 186/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 187/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 188/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 189/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 190/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 191/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 192/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 193/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 194/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 195/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 196/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 197/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 198/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 199/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 200/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 0.0010 - val_loss: 0.0010
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
# Visualization
plt.figure(figsize=(8, 6))

# Plot actual prices (All data)
plt.plot(df.index[:train_size], df['Price'][:train_size], label='Train', color='blue')

plt.plot(df.index[train_size:], df['Price'][train_size:], label='Test', color='orange')

# Plot predicted prices on the test set
test_data_start = df.index[train_size + n_lookback]  
test_data_end = df.index[-1]
plt.plot(df.index[train_size + n_lookback: len(Y_pred_test) + train_size + n_lookback], Y_pred_test, label='Predict_Test', color='green')


# Plot predicted prices in the future
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:]  # Ngày bắt đầu sau ngày cuối cùng của dữ liệu
plt.plot(future_dates, future_predictions, label='Predict_90days', color='purple')
plt.plot(future_dates[:60], future_predictions[:60], label='Predict_60days', color='blue')
plt.plot(future_dates[:30], future_predictions[:30], label='Predict_30days', color='red')

# plt.title('VCB Stock Price Forecast using MLP 9:1')
plt.xlabel('Date')
plt.ylabel('Close Price (VND)')
plt.legend()
plt.grid(True)  
plt.show()

# %%
# Create a new dataframe containing dates and future predicted values
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:] 
future_df = pd.DataFrame({'Date': future_dates, 'Forecast': future_predictions.flatten()}) 
future_df.set_index('Date', inplace=True)

# Print the forecast results for the next 90 days
print("Forecast VCB stock prices for the next 90 days:")
print(future_df)
# Out:
# Forecast VCB stock prices for the next 90 days:
#                 Forecast
# Date
# 2024-06-01  89423.578125
# 2024-06-02  89566.804688
# 2024-06-03  90953.218750
# 2024-06-04  90899.609375
# 2024-06-05  90634.539062
# ...                  ...
# 2024-08-25  93352.679688
# 2024-08-26  95423.000000
# 2024-08-27  94215.992188
# 2024-08-28  93446.484375
# 2024-08-29  91593.054688
#
# [90 rows x 1 columns]

# %%
# Calculate RMSE, MAPE, and MAE on the test set
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = mean_absolute_percentage_error(y_true, y_pred) * 100
    mae = mean_absolute_error(y_true, y_pred)
    return rmse, mape, mae

rmse, mape, mae = calculate_metrics(Y_test, Y_pred_test)

print('RMSE:', rmse)
print('MAPE:', mape, '%')
print('MAE:', mae)
# Out:
# RMSE: 2643.177686539535
# MAPE: 2.3804571505807846 %
# MAE: 2123.7484285201162

# %% [markdown]
# ## CTG

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None
tf.random.set_seed(0)

# Load data
data = pd.read_csv('../../Dataset/VCB.csv')
df = data[['Date','Close']]
df.rename(columns={'Close': 'Price'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values('Date',inplace=True)
df.set_index('Date',inplace=True)
y = df['Price'].values.reshape(-1, 1)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
y_norm = scaler.fit_transform(y)

# Split data into train and test (90/10)
train_size = int(len(y_norm) * 0.9)
y_train, y_test = y_norm[:train_size], y_norm[train_size:]

# Create input and output sequences
def create_sequences(data, n_lookback, n_forecast):
    X, Y = [], []
    for i in range(n_lookback, len(data) - n_forecast + 1):
        X.append(data[i - n_lookback: i])
        Y.append(data[i: i + n_forecast])
    return np.array(X), np.array(Y)

n_lookback = 60
n_forecast = 1  # Predict time step
X_train, Y_train = create_sequences(y_train, n_lookback, n_forecast)
X_test, Y_test = create_sequences(y_test, n_lookback, n_forecast)

# Build and train the model
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(n_lookback,))) 
model.add(Dense(50, activation='relu'))                            
model.add(Dense(n_forecast))                                       
model.compile(loss='mean_squared_error', optimizer='adadelta')
model.fit(X_train.reshape(X_train.shape[0], -1), Y_train, epochs=200, validation_data=(X_test, Y_test), batch_size=32, verbose=1)

# Evaluate on the test set
Y_pred_test = model.predict(X_test.reshape(X_test.shape[0], -1))
Y_pred_test = scaler.inverse_transform(Y_pred_test)

# Reshape Y_test before inverse transforming
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))  # Reshape to 2D

# Predict future 30, 60, 90 days
last_sequence = y_norm[-n_lookback:].reshape(1, -1)
future_predictions = []
for i in range(90):
    next_pred = model.predict(last_sequence)
    future_predictions.append(next_pred)
    last_sequence = np.concatenate([last_sequence[:, 1:], next_pred], axis=1)  
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
# Out:
# Epoch 1/200
# c:\Users\vanma\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3772 - val_loss: 1.5748
# Epoch 2/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 0.3525 - val_loss: 1.4672
# Epoch 3/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 0.3285 - val_loss: 1.3636
# Epoch 4/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 0.3053 - val_loss: 1.2643
# Epoch 5/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.2829 - val_loss: 1.1686
# Epoch 6/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.2611 - val_loss: 1.0750
# Epoch 7/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.2399 - val_loss: 0.9808
# Epoch 8/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 0.2189 - val_loss: 0.8853
# Epoch 9/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 0.1978 - val_loss: 0.7911
# Epoch 10/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.1771 - val_loss: 0.7028
# Epoch 11/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.1579 - val_loss: 0.6228
# Epoch 12/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - loss: 0.1404 - val_loss: 0.5513
# Epoch 13/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 0.1245 - val_loss: 0.4866
# Epoch 14/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.1100 - val_loss: 0.4275
# Epoch 15/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.0967 - val_loss: 0.3734
# Epoch 16/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.0846 - val_loss: 0.3241
# Epoch 17/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0735 - val_loss: 0.2792
# Epoch 18/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.0635 - val_loss: 0.2388
# Epoch 19/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0545 - val_loss: 0.2025
# Epoch 20/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 0.0464 - val_loss: 0.1702
# Epoch 21/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 0.0392 - val_loss: 0.1416
# Epoch 22/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0328 - val_loss: 0.1165
# Epoch 23/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.0273 - val_loss: 0.0947
# Epoch 24/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 0.0225 - val_loss: 0.0759
# Epoch 25/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 0.0184 - val_loss: 0.0600
# Epoch 26/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 0.0149 - val_loss: 0.0466
# Epoch 27/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 0.0120 - val_loss: 0.0355
# Epoch 28/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0096 - val_loss: 0.0265
# Epoch 29/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.0077 - val_loss: 0.0194
# Epoch 30/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 0.0062 - val_loss: 0.0139
# Epoch 31/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0051 - val_loss: 0.0099
# Epoch 32/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 0.0043 - val_loss: 0.0070
# Epoch 33/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 0.0037 - val_loss: 0.0050
# Epoch 34/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 35/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 36/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 37/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 38/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 39/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 40/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 41/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 42/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 43/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 44/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 45/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 46/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 47/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 48/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 49/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 50/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 51/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 52/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 53/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 54/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 55/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 56/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 57/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 58/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 59/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.0024 - val_loss: 0.0019
# Epoch 60/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 61/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 62/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 63/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 64/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 65/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 66/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 67/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 68/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 69/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 70/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 71/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 72/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 0.0022 - val_loss: 0.0018
# Epoch 73/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 74/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 75/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 76/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 77/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 78/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 79/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 80/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 81/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 82/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 83/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 84/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 85/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 86/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 87/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 88/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 89/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 90/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 91/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 92/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 93/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 94/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 95/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 96/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 97/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 98/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 99/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 100/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 101/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.0020 - val_loss: 0.0016
# Epoch 102/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 103/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 104/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 105/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 106/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 107/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 108/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 109/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 110/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 111/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 112/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 113/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 114/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 115/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 116/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 117/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 118/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 119/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 120/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 121/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 122/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 123/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 124/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 125/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 126/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 127/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 128/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 129/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 130/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 131/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 132/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 133/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 134/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 135/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 136/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 137/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 138/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 139/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 140/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 141/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 142/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 143/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 144/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 145/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 146/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 147/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 148/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 149/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 150/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 151/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 152/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 153/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 154/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 155/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 156/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 157/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 158/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 159/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 160/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 161/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 162/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 163/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 164/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 165/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 166/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 167/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 168/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 169/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 170/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 171/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 172/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 173/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 174/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 175/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 176/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 177/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 178/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 179/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 180/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 181/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 182/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 183/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 184/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 185/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 186/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 187/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 188/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 189/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 190/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 191/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 192/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 193/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 194/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 195/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 196/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 197/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 198/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 199/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 200/200
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - val_loss: 0.0012
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
# Visualization
plt.figure(figsize=(8, 6))

# Plot actual prices (All data)
plt.plot(df.index[:train_size], df['Price'][:train_size], label='Train', color='blue')

plt.plot(df.index[train_size:], df['Price'][train_size:], label='Test', color='orange')

# Plot predicted prices on the test set
test_data_start = df.index[train_size + n_lookback]  
test_data_end = df.index[-1]
plt.plot(df.index[train_size + n_lookback: len(Y_pred_test) + train_size + n_lookback], Y_pred_test, label='Predict_Test', color='green')


# Plot predicted prices in the future
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:]  
plt.plot(future_dates, future_predictions, label='Predict_90days', color='purple')
plt.plot(future_dates[:60], future_predictions[:60], label='Predict_60days', color='blue')
plt.plot(future_dates[:30], future_predictions[:30], label='Predict_30days', color='red')

# plt.title('CTG Stock Price Forecast using MLP 9:1')
plt.xlabel('Date')
plt.ylabel('Close Price (VND)')
plt.legend()
plt.grid(True)  
plt.show()

# %%
# Create a new dataframe containing dates and future predicted values
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:] 
future_df = pd.DataFrame({'Date': future_dates, 'Forecast': future_predictions.flatten()}) 
future_df.set_index('Date', inplace=True)

# Print the forecast results for the next 90 days
print("Forecast VCB stock prices for the next 90 days:")
print(future_df)
# Out:
# Forecast VCB stock prices for the next 90 days:
#                 Forecast
# Date
# 2024-06-01  92328.101562
# 2024-06-02  92631.078125
# 2024-06-03  92195.960938
# 2024-06-04  92896.289062
# 2024-06-05  92650.375000
# ...                  ...
# 2024-08-25  94695.085938
# 2024-08-26  94499.773438
# 2024-08-27  94554.585938
# 2024-08-28  94515.773438
# 2024-08-29  94623.515625
#
# [90 rows x 1 columns]

# %%
# Calculate RMSE, MAPE, and MAE on the test set
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = mean_absolute_percentage_error(y_true, y_pred) * 100
    mae = mean_absolute_error(y_true, y_pred)
    return rmse, mape, mae

rmse, mape, mae = calculate_metrics(Y_test, Y_pred_test)

print('RMSE:', rmse)
print('MAPE:', mape, '%')
print('MAE:', mae)
# Out:
# RMSE: 2858.7157202843437
# MAPE: 2.7259661764141256 %
# MAE: 2436.841100933909

# %% [markdown]
# ## BID

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None
tf.random.set_seed(0)

# Load data
data = pd.read_csv('../../Dataset/BID.csv')
df = data[['Date','Close']]
df.rename(columns={'Close': 'Price'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values('Date',inplace=True)
df.set_index('Date',inplace=True)
y = df['Price'].values.reshape(-1, 1)

# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
y_norm = scaler.fit_transform(y)

# Split data into train and test (90/10)
train_size = int(len(y_norm) * 0.9)
y_train, y_test = y_norm[:train_size], y_norm[train_size:]

# Create input and output sequences
def create_sequences(data, n_lookback, n_forecast):
    X, Y = [], []
    for i in range(n_lookback, len(data) - n_forecast + 1):
        X.append(data[i - n_lookback: i])
        Y.append(data[i: i + n_forecast])
    return np.array(X), np.array(Y)

n_lookback = 60
n_forecast = 1  # Predict time step
X_train, Y_train = create_sequences(y_train, n_lookback, n_forecast)
X_test, Y_test = create_sequences(y_test, n_lookback, n_forecast)

# Build and train the model
model = Sequential()
model.add(Dense(100, activation='relu', input_shape=(n_lookback,))) 
model.add(Dense(50, activation='relu'))                            
model.add(Dense(n_forecast))                                       
model.compile(loss='mean_squared_error', optimizer='adadelta')
model.fit(X_train.reshape(X_train.shape[0], -1), Y_train, epochs=200, validation_data=(X_test, Y_test), batch_size=32, verbose=1)

# Evaluate on the test set
Y_pred_test = model.predict(X_test.reshape(X_test.shape[0], -1))
Y_pred_test = scaler.inverse_transform(Y_pred_test)

# Reshape Y_test before inverse transforming
Y_test = scaler.inverse_transform(Y_test.reshape(-1, 1))  # Reshape to 2D

# Predict future 30, 60, 90 days
last_sequence = y_norm[-n_lookback:].reshape(1, -1)
future_predictions = []
for i in range(90):
    next_pred = model.predict(last_sequence)
    future_predictions.append(next_pred)
    last_sequence = np.concatenate([last_sequence[:, 1:], next_pred], axis=1)  
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))
# Out:
# Epoch 1/200
# c:\Users\vanma\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1600 - val_loss: 0.6748
# Epoch 2/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.1446 - val_loss: 0.6085
# Epoch 3/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.1298 - val_loss: 0.5453
# Epoch 4/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.1158 - val_loss: 0.4850
# Epoch 5/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.1025 - val_loss: 0.4283
# Epoch 6/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.0901 - val_loss: 0.3758
# Epoch 7/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.0787 - val_loss: 0.3276
# Epoch 8/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 0.0683 - val_loss: 0.2835
# Epoch 9/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 0.0588 - val_loss: 0.2436
# Epoch 10/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 0.0504 - val_loss: 0.2077
# Epoch 11/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0429 - val_loss: 0.1759
# Epoch 12/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 0.0362 - val_loss: 0.1477
# Epoch 13/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 0.0305 - val_loss: 0.1231
# Epoch 14/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 0.0255 - val_loss: 0.1019
# Epoch 15/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 0.0214 - val_loss: 0.0837
# Epoch 16/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.0179 - val_loss: 0.0685
# Epoch 17/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 0.0150 - val_loss: 0.0558
# Epoch 18/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.0127 - val_loss: 0.0455
# Epoch 19/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 0.0109 - val_loss: 0.0373
# Epoch 20/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0095 - val_loss: 0.0310
# Epoch 21/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0084 - val_loss: 0.0261
# Epoch 22/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.0077 - val_loss: 0.0226
# Epoch 23/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 0.0071 - val_loss: 0.0200
# Epoch 24/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0067 - val_loss: 0.0181
# Epoch 25/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.0064 - val_loss: 0.0168
# Epoch 26/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - loss: 0.0061 - val_loss: 0.0158
# Epoch 27/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.0059 - val_loss: 0.0150
# Epoch 28/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.0057 - val_loss: 0.0143
# Epoch 29/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 0.0055 - val_loss: 0.0136
# Epoch 30/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 0.0053 - val_loss: 0.0130
# Epoch 31/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 0.0051 - val_loss: 0.0125
# Epoch 32/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.0049 - val_loss: 0.0120
# Epoch 33/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 0.0048 - val_loss: 0.0115
# Epoch 34/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 0.0046 - val_loss: 0.0110
# Epoch 35/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.0045 - val_loss: 0.0105
# Epoch 36/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.0043 - val_loss: 0.0101
# Epoch 37/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 0.0042 - val_loss: 0.0096
# Epoch 38/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 0.0040 - val_loss: 0.0092
# Epoch 39/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.0039 - val_loss: 0.0088
# Epoch 40/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.0038 - val_loss: 0.0084
# Epoch 41/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 0.0037 - val_loss: 0.0081
# Epoch 42/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 0.0036 - val_loss: 0.0077
# Epoch 43/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0035 - val_loss: 0.0074
# Epoch 44/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 0.0034 - val_loss: 0.0071
# Epoch 45/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.0033 - val_loss: 0.0068
# Epoch 46/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.0032 - val_loss: 0.0065
# Epoch 47/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 0.0032 - val_loss: 0.0063
# Epoch 48/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0031 - val_loss: 0.0061
# Epoch 49/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.0030 - val_loss: 0.0059
# Epoch 50/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 0.0030 - val_loss: 0.0057
# Epoch 51/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 0.0029 - val_loss: 0.0055
# Epoch 52/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0029 - val_loss: 0.0054
# Epoch 53/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 0.0028 - val_loss: 0.0052
# Epoch 54/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0028 - val_loss: 0.0051
# Epoch 55/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.0027 - val_loss: 0.0050
# Epoch 56/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 0.0027 - val_loss: 0.0048
# Epoch 57/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026 - val_loss: 0.0047
# Epoch 58/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 0.0026 - val_loss: 0.0046
# Epoch 59/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - loss: 0.0026 - val_loss: 0.0045
# Epoch 60/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.0025 - val_loss: 0.0044
# Epoch 61/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 0.0025 - val_loss: 0.0043
# Epoch 62/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 63/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 64/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 65/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.0024 - val_loss: 0.0040
# Epoch 66/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.0023 - val_loss: 0.0039
# Epoch 67/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 68/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 69/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 70/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 71/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 72/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 73/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 0.0022 - val_loss: 0.0035
# Epoch 74/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 75/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0021 - val_loss: 0.0034
# Epoch 76/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.0021 - val_loss: 0.0034
# Epoch 77/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 78/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020 - val_loss: 0.0033
# Epoch 79/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 80/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 81/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 82/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 83/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 84/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 85/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 86/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 87/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 88/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 89/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 90/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 91/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 92/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 93/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 94/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 95/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 96/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 97/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 98/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 99/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 100/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 101/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 102/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 103/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 0.0017 - val_loss: 0.0026
# Epoch 104/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 105/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 106/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 107/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 108/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 109/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 110/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 111/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 112/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 113/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 114/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 115/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 116/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 117/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 118/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 119/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 120/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 121/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 122/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 123/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 124/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 125/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 126/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 127/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 128/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 129/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 130/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 131/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 132/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 133/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 134/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 135/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 136/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 137/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 138/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 139/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 140/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 141/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 142/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 143/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 144/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 145/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 146/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 147/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 148/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 149/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 150/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 151/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 152/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 153/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 154/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 155/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 156/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 157/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 158/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 159/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 160/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 161/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 162/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 163/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 164/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 165/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 166/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 167/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 168/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 169/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 170/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 171/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 172/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 173/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 174/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 175/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 176/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 177/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 178/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 179/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 180/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 181/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 182/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 183/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 184/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 185/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 186/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 187/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 188/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 189/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 190/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 191/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 192/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 193/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 194/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 195/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 196/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 197/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 198/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 199/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 200/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 0.0011 - val_loss: 0.0016
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
# Visualization
plt.figure(figsize=(8, 6))

# Plot actual prices (All data)
plt.plot(df.index[:train_size], df['Price'][:train_size], label='Train', color='blue')

plt.plot(df.index[train_size:], df['Price'][train_size:], label='Test', color='orange')

# Plot predicted prices on the test set
test_data_start = df.index[train_size + n_lookback]  
test_data_end = df.index[-1]
plt.plot(df.index[train_size + n_lookback: len(Y_pred_test) + train_size + n_lookback], Y_pred_test, label='Predict_Test', color='green')


# Plot predicted prices in the future
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:]  # Ngày bắt đầu sau ngày cuối cùng của dữ liệu
plt.plot(future_dates, future_predictions, label='Predict_90days', color='purple')
plt.plot(future_dates[:60], future_predictions[:60], label='Predict_60days', color='blue')
plt.plot(future_dates[:30], future_predictions[:30], label='Predict_30days', color='red')

# plt.title('BID Stock Price Forecast using MLP 9:1')
plt.xlabel('Date')
plt.ylabel('Close Price (VND)')
plt.legend()
plt.grid(True)  
plt.show()

# %%
# Create a new dataframe containing dates and future predicted values
future_dates = pd.date_range(start=df.index[-1], periods=91)[1:] 
future_df = pd.DataFrame({'Date': future_dates, 'Forecast': future_predictions.flatten()}) 
future_df.set_index('Date', inplace=True)

# Print the forecast results for the next 90 days
print("Forecast VCB stock prices for the next 90 days:")
print(future_df)
# Out:
# Forecast VCB stock prices for the next 90 days:
#                 Forecast
# Date
# 2024-06-01  48454.917969
# 2024-06-02  49552.253906
# 2024-06-03  49593.230469
# 2024-06-04  49578.210938
# 2024-06-05  49788.960938
# ...                  ...
# 2024-08-25  47044.179688
# 2024-08-26  45579.976562
# 2024-08-27  47394.179688
# 2024-08-28  47889.621094
# 2024-08-29  47058.597656
#
# [90 rows x 1 columns]

# %%
# Calculate RMSE, MAPE, and MAE on the test set
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

def calculate_metrics(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mape = mean_absolute_percentage_error(y_true, y_pred) * 100
    mae = mean_absolute_error(y_true, y_pred)
    return rmse, mape, mae

rmse, mape, mae = calculate_metrics(Y_test, Y_pred_test)

print('RMSE:', rmse)
print('MAPE:', mape, '%')
print('MAE:', mae)
# Out:
# RMSE: 1809.6201231799475
# MAPE: 3.20267175634783 %
# MAE: 1442.4232142857143
